# %%
import numpy as np
import pandas as pd

# %%
# !pip install numpy>=2.0.0
# !pip install gensim
# Out:
# Collecting gensim
#   Downloading gensim-4.3.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.1 kB)
# Collecting numpy<2.0,>=1.18.5 (from gensim)
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.3 MB/s eta 0:00:00
# Collecting scipy<1.14.0,>=1.7.0 (from gensim)
#   Downloading scipy-1.13.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 2.5 MB/s eta 0:00:00
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.11/dist-packages (from gensim) (7.1.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open>=1.8.1->gensim) (1.17.2)
# Downloading gensim-4.3.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (26.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.7/26.7 MB 68.9 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 90.7 MB/s eta 0:00:00
# Downloading scipy-1.13.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.6/38.6 MB 16.2 MB/s eta 0:00:00
# Installing collected packages: numpy, scipy, gensim
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.15.3
#     Uninstalling scipy-1.15.3:
#       Successfully uninstalled scipy-1.15.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tsfresh 0.21.0 requires scipy>=1.14.0; python_version >= "3.10", but you have scipy 1.13.1 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# Successfully installed gensim-4.3.3 numpy-1.26.4 scipy-1.13.1

# %%
# !pip install gensim
# Out:
# Collecting gensim
#   Downloading gensim-4.3.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.1 kB)
# Collecting numpy<2.0,>=1.18.5 (from gensim)
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 599.7 kB/s eta 0:00:00
# Collecting scipy<1.14.0,>=1.7.0 (from gensim)
#   Downloading scipy-1.13.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 911.5 kB/s eta 0:00:00
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.11/dist-packages (from gensim) (7.1.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open>=1.8.1->gensim) (1.17.2)
# Downloading gensim-4.3.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (26.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.7/26.7 MB 19.7 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 21.9 MB/s eta 0:00:00
# Downloading scipy-1.13.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.6/38.6 MB 8.5 MB/s eta 0:00:00
# Installing collected packages: numpy, scipy, gensim
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.14.1
#     Uninstalling scipy-1.14.1:
#       Successfully uninstalled scipy-1.14.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# Successfully installed gensim-4.3.3 numpy-1.26.4 scipy-1.13.1

# %%
import gensim
import os

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
from nltk import sent_tokenize
from gensim.utils import simple_preprocess

story = []
for filename in os.listdir('data'):

    f = open(os.path.join('data',filename),encoding='utf-8', errors='ignore')
    corpus = f.read()
    raw_sent = sent_tokenize(corpus)
    for sent in raw_sent:
        story.append(simple_preprocess(sent))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3-710315412.py in <cell line: 0>()
#       3
#       4 story = []
# ----> 5 for filename in os.listdir('data'):
#       6
#       7     f = open(os.path.join('data',filename),encoding='utf-8', errors='ignore')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data'

# %%
story
# Out:
# [['clash',
#   'of',
#   'kings',
#   'book',
#   'two',
#   'of',
#   'song',
#   'of',
#   'ice',
#   'and',
#   'fire',
#   'by',
#   'george',
#   'martin',
#   'prologue',
#   'the',
#   'comet',
#   'tail',
#   'spread',
#   'across',
#   'the',
#   'dawn',
#   'red',
#   'slash',
#   'that',
#   'bled',
#   'above',
#   'the',
#   'crags',
#   'of',
#   'dragonstone',
#   'like',
#   'wound',
#   'in',
#   'the',
#   'pink',
#   'and',
#   'purple',
#   'sky'],
#  ['the',
#   'maester',
#   'stood',
#   'on',
#   'the',
#   'windswept',
#   'balcony',
#   'outside',
#   'his',
#   'chambers'],
#  ['it', 'was', 'here', 'the', 'ravens', 'came', 'after', 'long', 'flight'],
#  ['their',
#   'droppings',
#   'speckled',
#   'the',
#   'gargoyles',
#   'that',
#   'rose',
#   'twelve',
#   'feet',
#   'tall',
#   'on',
#   'either',
#   'side',
#   'of',
#   'him',
#   'hellhound',
#   'and',
#   'wyvern',
#   'two',
#   'of',
#   'the',
#   'thousand',
#   'that',
#   'brooded',
#   'over',
#   'the',
#   'walls',
#   'of',
#   'the',
#   'ancient',
#   'fortress'],
#  ['when',
#   'first',
#   'he',
#   'came',
#   'to',
#   'dragonstone',
#   'the',
#   'army',
#   'of',
#   'stone',
#   'grotesques',
#   'had',
#   'made',
#   'him',
#   'uneasy',
#   'but',
#   'as',
#   'the',
#   'years',
#   'passed',
#   'he',
#   'had',
#   'grown',
#   'used',
#   'to',
#   'them'],
#  ['now', 'he', 'thought', 'of', 'them', 'as', 'old', 'friends'],
#  ['the',
#   'three',
#   'of',
#   'them',
#   'watched',
#   'the',
#   'sky',
#   'together',
#   'with',
#   'foreboding'],
#  ['the', 'maester', 'did', 'not', 'believe', 'in', 'omens'],
#  ['and', 'yet'],
#  [],
#  [],
#  ['old',
#   'as',
#   'he',
#   'was',
#   'cressen',
#   'had',
#   'never',
#   'seen',
#   'comet',
#   'half',
#   'so',
#   'bright',
#   'nor',
#   'yet',
#   'that',
#   'color',
#   'that',
#   'terrible',
#   'color',
#   'the',
#   'color',
#   'of',
#   'blood',
#   'and',
#   'flame',
#   'and',
#   'sunsets'],
#  ['he',
#   'wondered',
#   'if',
#   'his',
#   'gargoyles',
#   'had',
#   'ever',
#   'seen',
#   'its',
#   'like'],
#  ['they',
#   'had',
#   'been',
#   'here',
#   'so',
#   'much',
#   'longer',
#   'than',
#   'he',
#   'had',
#   'and',
#   'would',
#   'still',
#   'be',
#   'here',
#   'long',
#   'after',
#   'he',
#   'was',
#   'gone'],
#  ['if', 'stone', 'tongues', 'could', 'speak'],
#  [],
#  [],
#  ['such', 'folly'],
#  ['he',
#   'leaned',
#   'against',
#   'the',
#   'battlement',
#   'the',
#   'sea',
#   'crashing',
#   'beneath',
#   'him',
#   'the',
#   'black',
#   'stone',
#   'rough',
#   'beneath',
#   'his',
#   'fingers'],
#  ['talking', 'gargoyles', 'and', 'prophecies', 'in', 'the', 'sky'],
#  ['am', 'an', 'old', 'done', 'man', 'grown', 'giddy', 'as', 'child', 'again'],
#  ['had',
#   'lifetime',
#   'hard',
#   'won',
#   'wisdom',
#   'fled',
#   'him',
#   'along',
#   'with',
#   'his',
#   'health',
#   'and',
#   'strength'],
#  ['he',
#   'was',
#   'maester',
#   'trained',
#   'and',
#   'chained',
#   'in',
#   'the',
#   'great',
#   'citadel',
#   'of',
#   'oldtown'],
#  ['what',
#   'had',
#   'he',
#   'come',
#   'to',
#   'when',
#   'superstition',
#   'filled',
#   'his',
#   'head',
#   'as',
#   'if',
#   'he',
#   'were',
#   'an',
#   'ignorant',
#   'fieldhand'],
#  ['and', 'yet'],
#  [],
#  [],
#  ['and', 'yet'],
#  [],
#  [],
#  ['the',
#   'comet',
#   'burned',
#   'even',
#   'by',
#   'day',
#   'now',
#   'while',
#   'pale',
#   'grey',
#   'steam',
#   'rose',
#   'from',
#   'the',
#   'hot',
#   'vents',
#   'of',
#   'dragonmont',
#   'behind',
#   'the',
#   'castle',
#   'and',
#   'yestermorn',
#   'white',
#   'raven',
#   'had',
#   'brought',
#   'word',
#   'from',
#   'the',
#   'citadel',
#   'itself',
#   'word',
#   'long',
#   'expected',
#   'but',
#   'no',
#   'less',
#   'fearful',
#   'for',
#   'all',
#   'that',
#   'word',
#   'of',
#   'summer',
#   'end'],
#  ['omens', 'all'],
#  ['too', 'many', 'to', 'deny'],
#  ['what', 'does', 'it', 'all', 'mean'],
#  ['he', 'wanted', 'to', 'cry'],
#  ['page', 'maester', 'cressen', 'we', 'have', 'visitors'],
#  ['pylos',
#   'spoke',
#   'softly',
#   'as',
#   'if',
#   'loath',
#   'to',
#   'disturb',
#   'cressen',
#   'solemn',
#   'meditations'],
#  ['had',
#   'he',
#   'known',
#   'what',
#   'drivel',
#   'filled',
#   'his',
#   'head',
#   'he',
#   'would',
#   'have',
#   'shouted'],
#  ['the', 'princess', 'would', 'see', 'the', 'white', 'raven'],
#  ['ever',
#   'correct',
#   'pylos',
#   'called',
#   'her',
#   'princess',
#   'now',
#   'as',
#   'her',
#   'lord',
#   'father',
#   'was',
#   'king'],
#  ['king',
#   'of',
#   'smoking',
#   'rock',
#   'in',
#   'the',
#   'great',
#   'salt',
#   'sea',
#   'yet',
#   'king',
#   'nonetheless'],
#  ['her', 'fool', 'is', 'with', 'her'],
#  ['the',
#   'old',
#   'man',
#   'turned',
#   'away',
#   'from',
#   'the',
#   'dawn',
#   'keeping',
#   'hand',
#   'on',
#   'his',
#   'wyvern',
#   'to',
#   'steady',
#   'himself'],
#  ['help', 'me', 'to', 'my', 'chair', 'and', 'show', 'them', 'in'],
#  ['taking', 'his', 'arm', 'pylos', 'led', 'him', 'inside'],
#  ['in',
#   'his',
#   'youth',
#   'cressen',
#   'had',
#   'walked',
#   'briskly',
#   'but',
#   'he',
#   'was',
#   'not',
#   'far',
#   'from',
#   'his',
#   'eightieth',
#   'name',
#   'day',
#   'now',
#   'and',
#   'his',
#   'legs',
#   'were',
#   'frail',
#   'and',
#   'unsteady'],
#  ['two',
#   'years',
#   'past',
#   'he',
#   'had',
#   'fallen',
#   'and',
#   'shattered',
#   'hip',
#   'and',
#   'it',
#   'had',
#   'never',
#   'mended',
#   'properly'],
#  ['last',
#   'year',
#   'when',
#   'he',
#   'took',
#   'ill',
#   'the',
#   'citadel',
#   'had',
#   'sent',
#   'pylos',
#   'out',
#   'from',
#   'oldtown',
#   'mere',
#   'days',
#   'before',
#   'lord',
#   'stannis',
#   'had',
#   'closed',
#   'the',
#   'isle'],
#  [],
#  [],
#  ['to',
#   'help',
#   'him',
#   'in',
#   'his',
#   'labors',
#   'it',
#   'was',
#   'said',
#   'but',
#   'cressen',
#   'knew',
#   'the',
#   'truth'],
#  ['pylos', 'had', 'come', 'to', 'replace', 'him', 'when', 'he', 'died'],
#  ['he', 'did', 'not', 'mind'],
#  ['someone',
#   'must',
#   'take',
#   'his',
#   'place',
#   'and',
#   'sooner',
#   'than',
#   'he',
#   'would',
#   'like'],
#  [],
#  [],
#  ['he',
#   'let',
#   'the',
#   'younger',
#   'man',
#   'settle',
#   'him',
#   'behind',
#   'his',
#   'books',
#   'and',
#   'papers'],
#  ['go', 'bring', 'her'],
#  ['it', 'is', 'ill', 'to', 'keep', 'lady', 'waiting'],
#  ['he',
#   'waved',
#   'hand',
#   'feeble',
#   'gesture',
#   'of',
#   'haste',
#   'from',
#   'man',
#   'no',
#   'longer',
#   'capable',
#   'of',
#   'hastening'],
#  ['his',
#   'flesh',
#   'was',
#   'wrinkled',
#   'and',
#   'spotted',
#   'the',
#   'skin',
#   'so',
#   'papery',
#   'thin',
#   'that',
#   'he',
#   'could',
#   'see',
#   'the',
#   'web',
#   'of',
#   'veins',
#   'and',
#   'the',
#   'shape',
#   'of',
#   'bones',
#   'beneath'],
#  ['and',
#   'how',
#   'they',
#   'trembled',
#   'these',
#   'hands',
#   'of',
#   'his',
#   'that',
#   'had',
#   'once',
#   'been',
#   'so',
#   'sure',
#   'and',
#   'deft'],
#  [],
#  [],
#  ['when',
#   'pylos',
#   'returned',
#   'the',
#   'girl',
#   'came',
#   'with',
#   'him',
#   'shy',
#   'as',
#   'ever'],
#  ['behind',
#   'her',
#   'shuffling',
#   'and',
#   'hopping',
#   'in',
#   'that',
#   'queer',
#   'sideways',
#   'walk',
#   'of',
#   'his',
#   'came',
#   'her',
#   'fool'],
#  ['on',
#   'his',
#   'head',
#   'was',
#   'mock',
#   'helm',
#   'fashioned',
#   'from',
#   'an',
#   'old',
#   'tin',
#   'bucket',
#   'with',
#   'rack',
#   'of',
#   'deer',
#   'antlers',
#   'strapped',
#   'to',
#   'the',
#   'crown',
#   'and',
#   'hung',
#   'with',
#   'cowbells'],
#  ['with',
#   'his',
#   'every',
#   'lurching',
#   'step',
#   'the',
#   'bells',
#   'rang',
#   'each',
#   'with',
#   'different',
#   'voice',
#   'clang',
#   'dang',
#   'bong',
#   'dong',
#   'ring',
#   'ling',
#   'clong',
#   'clong',
#   'clong'],
#  ['who', 'comes', 'to', 'see', 'us', 'so', 'early', 'pylos'],
#  ['cressen', 'said'],
#  ['it', 'me', 'and', 'patches', 'maester'],
#  ['guileless', 'blue', 'eyes', 'blinked', 'at', 'him'],
#  ['hers', 'was', 'not', 'pretty', 'face', 'alas'],
#  ['the',
#   'child',
#   'had',
#   'her',
#   'lord',
#   'father',
#   'square',
#   'jut',
#   'of',
#   'jaw',
#   'and',
#   'her',
#   'mother',
#   'unfortunate',
#   'ears',
#   'along',
#   'with',
#   'disfigurement',
#   'all',
#   'her',
#   'own',
#   'the',
#   'legacy',
#   'of',
#   'the',
#   'bout',
#   'of',
#   'greyscale',
#   'that',
#   'had',
#   'almost',
#   'claimed',
#   'her',
#   'in',
#   'the',
#   'crib'],
#  ['across',
#   'half',
#   'one',
#   'cheek',
#   'and',
#   'well',
#   'down',
#   'her',
#   'neck',
#   'her',
#   'flesh',
#   'was',
#   'stiff',
#   'and',
#   'dead',
#   'the',
#   'skin',
#   'cracked',
#   'and',
#   'flaking',
#   'mottled',
#   'black',
#   'and',
#   'grey',
#   'and',
#   'stony',
#   'to',
#   'the',
#   'touch'],
#  ['pylos', 'said', 'we', 'might', 'see', 'the', 'white', 'raven'],
#  ['indeed', 'you', 'may', 'cressen', 'answered'],
#  ['as', 'if', 'he', 'would', 'ever', 'deny', 'her'],
#  ['she', 'had', 'been', 'denied', 'too', 'often', 'in', 'her', 'time'],
#  ['her', 'name', 'was', 'shireen'],
#  ['she',
#   'would',
#   'be',
#   'ten',
#   'on',
#   'her',
#   'next',
#   'name',
#   'day',
#   'and',
#   'she',
#   'was',
#   'the',
#   'saddest',
#   'child',
#   'that',
#   'maester',
#   'cressen',
#   'had',
#   'ever',
#   'known'],
#  ['her',
#   'sadness',
#   'is',
#   'my',
#   'shame',
#   'the',
#   'old',
#   'man',
#   'thought',
#   'another',
#   'mark',
#   'of',
#   'my',
#   'failure'],
#  ['maester',
#   'pylos',
#   'do',
#   'me',
#   'kindness',
#   'and',
#   'bring',
#   'the',
#   'bird',
#   'down',
#   'from',
#   'the',
#   'rookery',
#   'for',
#   'the',
#   'lady',
#   'shireen'],
#  ['it', 'would', 'be', 'my', 'pleasure'],
#  ['pylos',
#   'was',
#   'polite',
#   'youth',
#   'no',
#   'more',
#   'than',
#   'five',
#   'and',
#   'twenty',
#   'yet',
#   'solemn',
#   'as',
#   'man',
#   'of',
#   'sixty'],
#  ['if',
#   'only',
#   'he',
#   'had',
#   'more',
#   'humor',
#   'more',
#   'life',
#   'in',
#   'him',
#   'that',
#   'was',
#   'what',
#   'was',
#   'needed',
#   'here'],
#  ['grim',
#   'places',
#   'needed',
#   'lightening',
#   'not',
#   'solemnity',
#   'and',
#   'dragonstone',
#   'was',
#   'grim',
#   'beyond',
#   'doubt',
#   'lonely',
#   'citadel',
#   'in',
#   'the',
#   'wet',
#   'waste',
#   'surrounded',
#   'by',
#   'storm',
#   'and',
#   'salt',
#   'with',
#   'the',
#   'smoking',
#   'shadow',
#   'of',
#   'the',
#   'mountain',
#   'at',
#   'its',
#   'back'],
#  ['maester',
#   'must',
#   'go',
#   'where',
#   'he',
#   'is',
#   'sent',
#   'so',
#   'cressen',
#   'had',
#   'come',
#   'here',
#   'with',
#   'his',
#   'lord',
#   'some',
#   'twelve',
#   'years',
#   'past',
#   'and',
#   'he',
#   'had',
#   'served',
#   'and',
#   'served',
#   'well'],
#  ['yet',
#   'he',
#   'had',
#   'never',
#   'loved',
#   'dragonstone',
#   'nor',
#   'ever',
#   'felt',
#   'truly',
#   'at',
#   'home',
#   'here'],
#  ['of',
#   'late',
#   'when',
#   'he',
#   'woke',
#   'from',
#   'restless',
#   'dreams',
#   'in',
#   'which',
#   'the',
#   'red',
#   'woman',
#   'figured',
#   'disturbingly',
#   'he',
#   'often',
#   'did',
#   'not',
#   'know',
#   'where',
#   'he',
#   'was'],
#  ['page',
#   'the',
#   'fool',
#   'turned',
#   'his',
#   'patched',
#   'and',
#   'piebald',
#   'head',
#   'to',
#   'watch',
#   'pylos',
#   'climb',
#   'the',
#   'steep',
#   'iron',
#   'steps',
#   'to',
#   'the',
#   'rookery'],
#  ['his', 'bells', 'rang', 'with', 'the', 'motion'],
#  ['under',
#   'the',
#   'sea',
#   'the',
#   'birds',
#   'have',
#   'scales',
#   'for',
#   'feathers',
#   'he',
#   'said',
#   'clang',
#   'langing'],
#  ['know', 'know', 'oh', 'oh', 'oh'],
#  ['even', 'for', 'fool', 'patchface', 'was', 'sorry', 'thing'],
#  ['perhaps',
#   'once',
#   'he',
#   'could',
#   'evoke',
#   'gales',
#   'of',
#   'laughter',
#   'with',
#   'quip',
#   'but',
#   'the',
#   'sea',
#   'had',
#   'taken',
#   'that',
#   'power',
#   'from',
#   'him',
#   'along',
#   'with',
#   'half',
#   'his',
#   'wits',
#   'and',
#   'all',
#   'his',
#   'memory'],
#  ['he',
#   'was',
#   'soft',
#   'and',
#   'obese',
#   'subject',
#   'to',
#   'twitches',
#   'and',
#   'trembles',
#   'incoherent',
#   'as',
#   'often',
#   'as',
#   'not'],
#  ['the',
#   'girl',
#   'was',
#   'the',
#   'only',
#   'one',
#   'who',
#   'laughed',
#   'at',
#   'him',
#   'now',
#   'the',
#   'only',
#   'one',
#   'who',
#   'cared',
#   'if',
#   'he',
#   'lived',
#   'or',
#   'died'],
#  ['an',
#   'ugly',
#   'little',
#   'girl',
#   'and',
#   'sad',
#   'fool',
#   'and',
#   'maester',
#   'makes',
#   'three'],
#  [],
#  [],
#  ['now', 'there', 'is', 'tale', 'to', 'make', 'men', 'weep'],
#  ['sit', 'with', 'me', 'child'],
#  ['cressen', 'beckoned', 'her', 'closer'],
#  ['this', 'is', 'early', 'to', 'come', 'calling', 'scarce', 'past', 'dawn'],
#  ['you', 'should', 'be', 'snug', 'in', 'your', 'bed'],
#  ['had', 'bad', 'dreams', 'shireen', 'told', 'him'],
#  ['about', 'the', 'dragons'],
#  ['they', 'were', 'coming', 'to', 'eat', 'me'],
#  ['the',
#   'child',
#   'had',
#   'been',
#   'plagued',
#   'by',
#   'nightmares',
#   'as',
#   'far',
#   'back',
#   'as',
#   'maester',
#   'cressen',
#   'could',
#   'recall'],
#  ['we', 'have', 'talked', 'of', 'this', 'before', 'he', 'said', 'gently'],
#  ['the', 'dragons', 'cannot', 'come', 'to', 'life'],
#  ['they', 'are', 'carved', 'of', 'stone', 'child'],
#  ['in',
#   'olden',
#   'days',
#   'our',
#   'island',
#   'was',
#   'the',
#   'westernmost',
#   'outpost',
#   'of',
#   'the',
#   'great',
#   'freehold',
#   'of',
#   'valyria'],
#  ['it',
#   'was',
#   'the',
#   'valyrians',
#   'who',
#   'raised',
#   'this',
#   'citadel',
#   'and',
#   'they',
#   'had',
#   'ways',
#   'of',
#   'shaping',
#   'stone',
#   'since',
#   'lost',
#   'to',
#   'us'],
#  ['castle',
#   'must',
#   'have',
#   'towers',
#   'wherever',
#   'two',
#   'walls',
#   'meet',
#   'at',
#   'an',
#   'angle',
#   'for',
#   'defense'],
#  ['the',
#   'valyrians',
#   'fashioned',
#   'these',
#   'towers',
#   'in',
#   'the',
#   'shape',
#   'of',
#   'dragons',
#   'to',
#   'make',
#   'their',
#   'fortress',
#   'seem',
#   'more',
#   'fearsome',
#   'just',
#   'as',
#   'they',
#   'crowned',
#   'their',
#   'walls',
#   'with',
#   'thousand',
#   'gargoyles',
#   'instead',
#   'of',
#   'simple',
#   'crenellations'],
#  ['he',
#   'took',
#   'her',
#   'small',
#   'pink',
#   'hand',
#   'in',
#   'his',
#   'own',
#   'frail',
#   'spotted',
#   'one',
#   'and',
#   'gave',
#   'it',
#   'gentle',
#   'squeeze'],
#  ['so', 'you', 'see', 'there', 'is', 'nothing', 'to', 'fear'],
#  ['shireen', 'was', 'unconvinced'],
#  ['what', 'about', 'the', 'thing', 'in', 'the', 'sky'],
#  ['dalla',
#   'and',
#   'matrice',
#   'were',
#   'talking',
#   'by',
#   'the',
#   'well',
#   'and',
#   'dalla',
#   'said',
#   'she',
#   'heard',
#   'the',
#   'red',
#   'woman',
#   'tell',
#   'mother',
#   'that',
#   'it',
#   'was',
#   'dragonshreath'],
#  ['if',
#   'the',
#   'dragons',
#   'are',
#   'breathing',
#   'doesn',
#   'that',
#   'mean',
#   'they',
#   'are',
#   'coming',
#   'to',
#   'life'],
#  ['the',
#   'red',
#   'woman',
#   'maester',
#   'cressen',
#   'thought',
#   'sourly',
#   'illenough',
#   'that',
#   'she',
#   'filled',
#   'the',
#   'head',
#   'of',
#   'the',
#   'mother',
#   'with',
#   'her',
#   'madness',
#   'must',
#   'she',
#   'poison',
#   'the',
#   'daughter',
#   'dreams',
#   'as',
#   'well'],
#  ['he',
#   'would',
#   'have',
#   'stern',
#   'word',
#   'with',
#   'dalla',
#   'warn',
#   'her',
#   'not',
#   'to',
#   'spread',
#   'such',
#   'tales'],
#  ['the', 'thing', 'in', 'the', 'sky', 'is', 'comet', 'sweet', 'child'],
#  ['star', 'with', 'tail', 'lost', 'in', 'the', 'heavens'],
#  ['it',
#   'will',
#   'be',
#   'gone',
#   'soon',
#   'enough',
#   'never',
#   'to',
#   'be',
#   'seen',
#   'again',
#   'in',
#   'our',
#   'lifetimes'],
#  ['watch', 'and', 'see'],
#  ['shireen', 'gave', 'brave', 'little', 'nod'],
#  ['mother',
#   'said',
#   'the',
#   'white',
#   'raven',
#   'means',
#   'it',
#   'not',
#   'summer',
#   'anymore'],
#  ['that', 'is', 'so', 'my', 'lady'],
#  ['the', 'white', 'ravens', 'fly', 'only', 'from', 'the', 'citadel'],
#  ['cressen',
#   'fingers',
#   'went',
#   'to',
#   'the',
#   'chain',
#   'about',
#   'his',
#   'neck',
#   'each',
#   'link',
#   'forged',
#   'from',
#   'different',
#   'metal',
#   'each',
#   'symbolizing',
#   'his',
#   'mastery',
#   'of',
#   'another',
#   'branch',
#   'of',
#   'learning',
#   'the',
#   'maester',
#   'collar',
#   'mark',
#   'of',
#   'his',
#   'order'],
#  ['in',
#   'the',
#   'pride',
#   'of',
#   'his',
#   'youth',
#   'he',
#   'had',
#   'worn',
#   'it',
#   'easily',
#   'but',
#   'now',
#   'it',
#   'seemed',
#   'heavy',
#   'to',
#   'him',
#   'the',
#   'metal',
#   'cold',
#   'against',
#   'his',
#   'skin'],
#  ['they',
#   'are',
#   'larger',
#   'than',
#   'other',
#   'ravens',
#   'and',
#   'more',
#   'clever',
#   'bred',
#   'to',
#   'carry',
#   'only',
#   'the',
#   'most',
#   'important',
#   'messages'],
#  ['this',
#   'one',
#   'came',
#   'to',
#   'tell',
#   'us',
#   'that',
#   'the',
#   'conclave',
#   'has',
#   'met',
#   'considered',
#   'the',
#   'reports',
#   'and',
#   'measurements',
#   'made',
#   'by',
#   'maesters',
#   'all',
#   'over',
#   'the',
#   'realm',
#   'and',
#   'declared',
#   'this',
#   'great',
#   'summer',
#   'done',
#   'at',
#   'last'],
#  ['ten',
#   'years',
#   'two',
#   'turns',
#   'and',
#   'sixteen',
#   'days',
#   'it',
#   'lasted',
#   'the',
#   'longest',
#   'summer',
#   'in',
#   'living',
#   'memory'],
#  ['will', 'it', 'get', 'cold', 'now'],
#  ['shireen',
#   'was',
#   'summer',
#   'child',
#   'and',
#   'had',
#   'never',
#   'known',
#   'true',
#   'cold'],
#  ['in', 'time', 'cressen', 'replied'],
#  ['if',
#   'the',
#   'gods',
#   'are',
#   'good',
#   'they',
#   'will',
#   'grant',
#   'us',
#   'warm',
#   'autumn',
#   'and',
#   'bountiful',
#   'harvests',
#   'so',
#   'we',
#   'might',
#   'prepare',
#   'for',
#   'the',
#   'winter',
#   'to',
#   'come'],
#  ['the',
#   'smallfolk',
#   'said',
#   'that',
#   'long',
#   'summer',
#   'meant',
#   'an',
#   'even',
#   'longer',
#   'winter',
#   'but',
#   'the',
#   'maester',
#   'saw',
#   'no',
#   'reason',
#   'to',
#   'frighten',
#   'the',
#   'child',
#   'with',
#   'such',
#   'tales'],
#  ['page', 'patchface', 'rang', 'his', 'bells'],
#  ['it', 'is', 'always', 'summer', 'under', 'the', 'sea', 'he', 'intoned'],
#  ['the',
#   'merwives',
#   'wear',
#   'nennymoans',
#   'in',
#   'their',
#   'hair',
#   'and',
#   'weave',
#   'gowns',
#   'of',
#   'silver',
#   'seaweed'],
#  ['know', 'know', 'oh', 'oh', 'oh'],
#  ['shireen', 'giggled'],
#  ['should', 'like', 'gown', 'of', 'silver', 'seaweed'],
#  ['under',
#   'the',
#   'sea',
#   'it',
#   'snows',
#   'up',
#   'said',
#   'the',
#   'fool',
#   'and',
#   'the',
#   'rain',
#   'is',
#   'dry',
#   'as',
#   'bone'],
#  ['know', 'know', 'oh', 'oh', 'oh'],
#  ['will', 'it', 'truly', 'snow'],
#  ['the', 'child', 'asked'],
#  ['it', 'will', 'cressen', 'said'],
#  ['but',
#   'not',
#   'for',
#   'years',
#   'yet',
#   'pray',
#   'and',
#   'then',
#   'not',
#   'for',
#   'long'],
#  ['ah', 'here', 'is', 'pylos', 'with', 'the', 'bird'],
#  ['shireen', 'gave', 'cry', 'of', 'delight'],
#  ['even',
#   'cressen',
#   'had',
#   'to',
#   'admit',
#   'the',
#   'bird',
#   'made',
#   'an',
#   'impressive',
#   'sight',
#   'white',
#   'as',
#   'snow',
#   'and',
#   'larger',
#   'than',
#   'any',
#   'hawk',
#   'with',
#   'the',
#   'bright',
#   'black',
#   'eyes',
#   'that',
#   'meant',
#   'it',
#   'was',
#   'no',
#   'mere',
#   'albino',
#   'but',
#   'truebred',
#   'white',
#   'raven',
#   'of',
#   'the',
#   'citadel'],
#  ['here', 'he', 'called'],
#  ['the',
#   'raven',
#   'spread',
#   'its',
#   'wings',
#   'leapt',
#   'into',
#   'the',
#   'air',
#   'and',
#   'flapped',
#   'noisily',
#   'across',
#   'the',
#   'room',
#   'to',
#   'land',
#   'on',
#   'the',
#   'table',
#   'beside',
#   'him'],
#  ['ll', 'see', 'to', 'your', 'breakfast', 'now', 'pylos', 'announced'],
#  ['cressen', 'nodded'],
#  ['this', 'is', 'the', 'lady', 'shireen', 'he', 'told', 'the', 'raven'],
#  ['the',
#   'bird',
#   'bobbed',
#   'its',
#   'pale',
#   'head',
#   'up',
#   'and',
#   'down',
#   'as',
#   'if',
#   'it',
#   'were',
#   'bowing'],
#  ['lady', 'it', 'croaked'],
#  ['lady'],
#  ['the', 'child', 'mouth', 'gaped', 'open'],
#  ['it', 'talks'],
#  ['few', 'words'],
#  ['as', 'said', 'they', 'are', 'clever', 'these', 'birds'],
#  ['clever',
#   'bird',
#   'clever',
#   'man',
#   'clever',
#   'clever',
#   'fool',
#   'said',
#   'patchface',
#   'jangling'],
#  ['oh', 'clever', 'clever', 'clever', 'fool'],
#  ['he', 'began', 'to', 'sing'],
#  ['the',
#   'shadows',
#   'come',
#   'to',
#   'dance',
#   'my',
#   'lord',
#   'dance',
#   'my',
#   'lord',
#   'dance',
#   'my',
#   'lord',
#   'he',
#   'sang',
#   'hopping',
#   'from',
#   'one',
#   'foot',
#   'to',
#   'the',
#   'other',
#   'and',
#   'back',
#   'again'],
#  ['the',
#   'shadows',
#   'come',
#   'to',
#   'stay',
#   'my',
#   'lord',
#   'stay',
#   'my',
#   'lord',
#   'stay',
#   'my',
#   'lord'],
#  ['he',
#   'jerked',
#   'his',
#   'head',
#   'with',
#   'each',
#   'word',
#   'the',
#   'bells',
#   'in',
#   'his',
#   'antlers',
#   'sending',
#   'up',
#   'clangor'],
#  ['the',
#   'white',
#   'raven',
#   'screamed',
#   'and',
#   'went',
#   'flapping',
#   'away',
#   'to',
#   'perch',
#   'on',
#   'the',
#   'iron',
#   'railing',
#   'of',
#   'the',
#   'rookery',
#   'stairs'],
#  ['shireen', 'seemed', 'to', 'grow', 'smaller'],
#  ['he', 'sings', 'that', 'all', 'the', 'time'],
#  ['told', 'him', 'to', 'stop', 'but', 'he', 'won'],
#  ['it', 'makes', 'me', 'scared'],
#  ['make', 'him', 'stop'],
#  ['and', 'how', 'do', 'do', 'that'],
#  ['the', 'old', 'man', 'wondered'],
#  ['once', 'might', 'have', 'silenced', 'him', 'forever', 'but', 'now'],
#  [],
#  [],
#  ['patchface', 'had', 'come', 'to', 'them', 'as', 'boy'],
#  ['lord',
#   'steffon',
#   'of',
#   'cherished',
#   'memory',
#   'had',
#   'found',
#   'him',
#   'in',
#   'volantis',
#   'across',
#   'the',
#   'narrow',
#   'sea'],
#  ['the',
#   'king',
#   'the',
#   'old',
#   'king',
#   'aerys',
#   'ii',
#   'targaryen',
#   'who',
#   'had',
#   'not',
#   'been',
#   'quite',
#   'so',
#   'mad',
#   'in',
#   'those',
#   'dayshad',
#   'sent',
#   'his',
#   'lordship',
#   'to',
#   'seek',
#   'bride',
#   'for',
#   'prince',
#   'rhaegar',
#   'who',
#   'had',
#   'no',
#   'sisters',
#   'to',
#   'wed',
#   'we',
#   'have',
#   'found',
#   'the',
#   'most',
#   'splendid',
#   'fool',
#   'he',
#   'wrote',
#   'cressen',
#   'fortnight',
#   'before',
#   'he',
#   'was',
#   'to',
#   'return',
#   'home',
#   'from',
#   'his',
#   'fruitless',
#   'mission'],
#  ['only',
#   'boy',
#   'yet',
#   'nimble',
#   'as',
#   'monkey',
#   'and',
#   'witty',
#   'as',
#   'dozen',
#   'courtiers'],
#  ['he',
#   'juggles',
#   'and',
#   'riddles',
#   'and',
#   'does',
#   'magic',
#   'and',
#   'he',
#   'can',
#   'sing',
#   'prettily',
#   'in',
#   'four',
#   'tongues'],
#  ['we',
#   'have',
#   'bought',
#   'his',
#   'freedom',
#   'and',
#   'hope',
#   'to',
#   'bring',
#   'him',
#   'home',
#   'with',
#   'us'],
#  ['robert',
#   'will',
#   'be',
#   'delighted',
#   'with',
#   'him',
#   'and',
#   'perhaps',
#   'in',
#   'time',
#   'he',
#   'will',
#   'even',
#   'teach',
#   'stannis',
#   'how',
#   'to',
#   'laugh'],
#  ['it', 'saddened', 'cressen', 'to', 'remember', 'that', 'letter'],
#  ['no',
#   'one',
#   'had',
#   'ever',
#   'taught',
#   'stannis',
#   'how',
#   'to',
#   'laugh',
#   'least',
#   'of',
#   'all',
#   'the',
#   'boy',
#   'patchface'],
#  ['the',
#   'storm',
#   'came',
#   'up',
#   'suddenly',
#   'howling',
#   'and',
#   'shipbreaker',
#   'bay',
#   'proved',
#   'the',
#   'truth',
#   'of',
#   'its',
#   'name'],
#  ['the',
#   'lord',
#   'two',
#   'masted',
#   'galley',
#   'windproud',
#   'broke',
#   'up',
#   'within',
#   'sight',
#   'of',
#   'his',
#   'castle'],
#  ['from',
#   'its',
#   'parapets',
#   'his',
#   'two',
#   'eldest',
#   'sons',
#   'had',
#   'watched',
#   'as',
#   'their',
#   'father',
#   'ship',
#   'was',
#   'smashed',
#   'against',
#   'the',
#   'rocks',
#   'and',
#   'swallowed',
#   'by',
#   'the',
#   'waters'],
#  ['hundred',
#   'oarsmen',
#   'and',
#   'sailors',
#   'went',
#   'down',
#   'with',
#   'lord',
#   'steffon',
#   'baratheon',
#   'and',
#   'his',
#   'lady',
#   'wife',
#   'and',
#   'for',
#   'days',
#   'thereafter',
#   'every',
#   'tide',
#   'left',
#   'fresh',
#   'crop',
#   'of',
#   'swollen',
#   'corpses',
#   'on',
#   'the',
#   'strand',
#   'below',
#   'storm',
#   'end'],
#  ['page', 'the', 'boy', 'washed', 'up', 'on', 'the', 'third', 'day'],
#  ['maester',
#   'cressen',
#   'had',
#   'come',
#   'down',
#   'with',
#   'the',
#   'rest',
#   'to',
#   'help',
#   'put',
#   'names',
#   'to',
#   'the',
#   'dead'],
#  ['when',
#   'they',
#   'found',
#   'the',
#   'fool',
#   'he',
#   'was',
#   'naked',
#   'his',
#   'skin',
#   'white',
#   'and',
#   'wrinkled',
#   'and',
#   'powdered',
#   'with',
#   'wet',
#   'sand'],
#  ['cressen',
#   'had',
#   'thought',
#   'him',
#   'another',
#   'corpse',
#   'but',
#   'when',
#   'jornmy',
#   'grabbed',
#   'his',
#   'ankles',
#   'to',
#   'drag',
#   'him',
#   'off',
#   'to',
#   'the',
#   'burial',
#   'wagon',
#   'the',
#   'boy',
#   'coughed',
#   'water',
#   'and',
#   'sat',
#   'up'],
#  ['to',
#   'his',
#   'dying',
#   'day',
#   'jornmy',
#   'had',
#   'sworn',
#   'that',
#   'patchface',
#   'flesh',
#   'was',
#   'clammy',
#   'cold'],
#  ['no',
#   'one',
#   'ever',
#   'explained',
#   'those',
#   'two',
#   'days',
#   'the',
#   'fool',
#   'had',
#   'been',
#   'lost',
#   'in',
#   'the',
#   'sea'],
#  ['the',
#   'fisherfolk',
#   'liked',
#   'to',
#   'say',
#   'mermaid',
#   'had',
#   'taught',
#   'him',
#   'to',
#   'breathe',
#   'water',
#   'in',
#   'return',
#   'for',
#   'his',
#   'seed'],
#  ['patchface', 'himself', 'had', 'said', 'nothing'],
#  ['the',
#   'witty',
#   'clever',
#   'lad',
#   'that',
#   'lord',
#   'steffon',
#   'had',
#   'written',
#   'of',
#   'never',
#   'reached',
#   'storm',
#   'end',
#   'the',
#   'boy',
#   'they',
#   'found',
#   'was',
#   'someone',
#   'else',
#   'broken',
#   'in',
#   'body',
#   'and',
#   'mind',
#   'hardly',
#   'capable',
#   'of',
#   'speech',
#   'much',
#   'less',
#   'of',
#   'wit'],
#  ['yet',
#   'his',
#   'fool',
#   'face',
#   'left',
#   'no',
#   'doubt',
#   'of',
#   'who',
#   'he',
#   'was'],
#  ['it',
#   'was',
#   'the',
#   'fashion',
#   'in',
#   'the',
#   'free',
#   'city',
#   'of',
#   'volantis',
#   'to',
#   'tattoo',
#   'the',
#   'faces',
#   'of',
#   'slaves',
#   'and',
#   'servants',
#   'from',
#   'neck',
#   'to',
#   'scalp',
#   'the',
#   'boy',
#   'skin',
#   'had',
#   'been',
#   'patterned',
#   'in',
#   'squares',
#   'of',
#   'red',
#   'and',
#   'green',
#   'motley'],
#  ['the',
#   'wretch',
#   'is',
#   'mad',
#   'and',
#   'in',
#   'pain',
#   'and',
#   'no',
#   'use',
#   'to',
#   'anyone',
#   'least',
#   'of',
#   'all',
#   'himself',
#   'declared',
#   'old',
#   'ser',
#   'harbert',
#   'the',
#   'castellan',
#   'of',
#   'storm',
#   'end',
#   'in',
#   'those',
#   'years'],
#  ['the',
#   'kindest',
#   'thing',
#   'you',
#   'could',
#   'do',
#   'for',
#   'that',
#   'one',
#   'is',
#   'fill',
#   'his',
#   'cup',
#   'with',
#   'the',
#   'milk',
#   'of',
#   'the',
#   'poppy'],
#  ['painless', 'sleep', 'and', 'there', 'an', 'end', 'to', 'it'],
#  ['he', 'bless', 'you', 'if', 'he', 'had', 'the', 'wit', 'for', 'it'],
#  ['but',
#   'cressen',
#   'had',
#   'refused',
#   'and',
#   'in',
#   'the',
#   'end',
#   'he',
#   'had',
#   'won'],
#  ['whether',
#   'patchface',
#   'had',
#   'gotten',
#   'any',
#   'joy',
#   'of',
#   'that',
#   'victory',
#   'he',
#   'could',
#   'not',
#   'say',
#   'not',
#   'even',
#   'today',
#   'so',
#   'many',
#   'years',
#   'later'],
#  ['the',
#   'shadows',
#   'come',
#   'to',
#   'dance',
#   'my',
#   'lord',
#   'dance',
#   'my',
#   'lord',
#   'dance',
#   'my',
#   'lord',
#   'the',
#   'fool',
#   'sang',
#   'on',
#   'swinging',
#   'his',
#   'head',
#   'and',
#   'making',
#   'his',
#   'bells',
#   'clang',
#   'and',
#   'clatter'],
#  ['bong', 'dong', 'ring', 'ling', 'bong', 'dong'],
#  ['lord', 'the', 'white', 'raven', 'shrieked'],
#  ['lord', 'lord', 'lord'],
#  ['fool',
#   'sings',
#   'what',
#   'he',
#   'will',
#   'the',
#   'maester',
#   'told',
#   'his',
#   'anxious',
#   'princess'],
#  ['you', 'must', 'not', 'take', 'his', 'words', 'to', 'heart'],
#  ['on',
#   'the',
#   'morrow',
#   'he',
#   'may',
#   'remember',
#   'another',
#   'song',
#   'and',
#   'this',
#   'one',
#   'will',
#   'never',
#   'be',
#   'heard',
#   'again'],
#  ['he',
#   'can',
#   'sing',
#   'prettily',
#   'in',
#   'four',
#   'tongues',
#   'lord',
#   'steffon',
#   'had',
#   'written'],
#  [],
#  [],
#  ['pylos', 'strode', 'through', 'the', 'door'],
#  ['maester', 'pardons'],
#  ['you', 'have', 'forgotten', 'the', 'porridge', 'cressen', 'said', 'amused'],
#  ['that', 'was', 'most', 'unlike', 'pylos'],
#  ['maester', 'ser', 'davos', 'returned', 'last', 'night'],
#  ['they', 'were', 'talking', 'of', 'it', 'in', 'the', 'kitchen'],
#  ['thought', 'you', 'would', 'want', 'to', 'know', 'at', 'once'],
#  ['davos'],
#  [],
#  [],
#  ['last', 'night', 'you', 'say'],
#  ['where', 'is', 'he'],
#  ['with', 'the', 'king'],
#  ['they', 'have', 'been', 'together', 'most', 'of', 'the', 'night'],
#  ['there',
#   'was',
#   'time',
#   'when',
#   'lord',
#   'stannis',
#   'would',
#   'have',
#   'woken',
#   'him',
#   'no',
#   'matter',
#   'the',
#   'hour',
#   'to',
#   'have',
#   'him',
#   'there',
#   'to',
#   'give',
#   'his',
#   'counsel'],
#  ['should', 'have', 'been', 'told', 'cressen', 'complained'],
#  ['should', 'have', 'been', 'woken'],
#  ['he', 'disentangled', 'his', 'fingers', 'from', 'shireen'],
#  ['pardons',
#   'my',
#   'lady',
#   'but',
#   'must',
#   'speak',
#   'with',
#   'your',
#   'lord',
#   'father'],
#  ['pylos', 'give', 'me', 'your', 'arm'],
#  ['there',
#   'are',
#   'too',
#   'many',
#   'steps',
#   'in',
#   'this',
#   'castle',
#   'and',
#   'it',
#   'seems',
#   'to',
#   'me',
#   'they',
#   'add',
#   'few',
#   'every',
#   'night',
#   'just',
#   'to',
#   'vex',
#   'me'],
#  ['shireen',
#   'and',
#   'patchface',
#   'followed',
#   'them',
#   'out',
#   'but',
#   'the',
#   'child',
#   'soon',
#   'grew',
#   'restless',
#   'with',
#   'the',
#   'old',
#   'man',
#   'creeping',
#   'pace',
#   'and',
#   'dashed',
#   'ahead',
#   'the',
#   'fool',
#   'lurching',
#   'after',
#   'her',
#   'with',
#   'his',
#   'cowbells',
#   'clanging',
#   'madly'],
#  ['castles',
#   'are',
#   'not',
#   'friendly',
#   'places',
#   'for',
#   'the',
#   'frail',
#   'cressen',
#   'was',
#   'reminded',
#   'as',
#   'he',
#   'descended',
#   'the',
#   'turnpike',
#   'stairs',
#   'of',
#   'page',
#   'sea',
#   'dragon',
#   'tower'],
#  ['lord',
#   'stannis',
#   'would',
#   'be',
#   'found',
#   'in',
#   'the',
#   'chamber',
#   'of',
#   'the',
#   'painted',
#   'table',
#   'atop',
#   'the',
#   'stone',
#   'drum',
#   'dragonstone',
#   'central',
#   'keep',
#   'so',
#   'named',
#   'for',
#   'the',
#   'way',
#   'its',
#   'ancient',
#   'walls',
#   'boomed',
#   'and',
#   'rumbled',
#   'during',
#   'storms'],
#  ['to',
#   'reach',
#   'him',
#   'they',
#   'must',
#   'cross',
#   'the',
#   'gallery',
#   'pass',
#   'through',
#   'the',
#   'middle',
#   'and',
#   'inner',
#   'walls',
#   'with',
#   'their',
#   'guardian',
#   'gargoyles',
#   'and',
#   'black',
#   'iron',
#   'gates',
#   'and',
#   'ascend',
#   'more',
#   'steps',
#   'than',
#   'cressen',
#   'cared',
#   'to',
#   'contemplate'],
#  ['young',
#   'men',
#   'climbed',
#   'steps',
#   'two',
#   'at',
#   'time',
#   'for',
#   'old',
#   'men',
#   'with',
#   'bad',
#   'hips',
#   'every',
#   'one',
#   'was',
#   'torment'],
#  ['but',
#   'lord',
#   'stannis',
#   'would',
#   'not',
#   'think',
#   'to',
#   'come',
#   'to',
#   'him',
#   'so',
#   'the',
#   'maester',
#   'resigned',
#   'himself',
#   'to',
#   'the',
#   'ordeal'],
#  ['he',
#   'had',
#   'pylos',
#   'to',
#   'help',
#   'him',
#   'at',
#   'the',
#   'least',
#   'and',
#   'for',
#   'that',
#   'he',
#   'was',
#   'grateful'],
#  ['shuffling',
#   'along',
#   'the',
#   'gallery',
#   'they',
#   'passed',
#   'before',
#   'row',
#   'of',
#   'tall',
#   'arched',
#   'windows',
#   'with',
#   'commanding',
#   'views',
#   'of',
#   'the',
#   'outer',
#   'bailey',
#   'the',
#   'curtain',
#   'wall',
#   'and',
#   'the',
#   'fishing',
#   'village',
#   'beyond'],
#  ['in',
#   'the',
#   'yard',
#   'archers',
#   'were',
#   'firing',
#   'at',
#   'practice',
#   'butts',
#   'to',
#   'the',
#   'call',
#   'of',
#   'notch',
#   'draw',
#   'loose'],
#  ['their',
#   'arrows',
#   'made',
#   'sound',
#   'like',
#   'flock',
#   'of',
#   'birds',
#   'taking',
#   'wing'],
#  ['guardsmen',
#   'strode',
#   'the',
#   'wallwalks',
#   'peering',
#   'between',
#   'the',
#   'gargoyles',
#   'on',
#   'the',
#   'host',
#   'camped',
#   'without'],
#  ['the',
#   'morning',
#   'air',
#   'was',
#   'hazy',
#   'with',
#   'the',
#   'smoke',
#   'of',
#   'cookfires',
#   'as',
#   'three',
#   'thousand',
#   'men',
#   'sat',
#   'down',
#   'to',
#   'break',
#   'their',
#   'fasts',
#   'beneath',
#   'the',
#   'banners',
#   'of',
#   'their',
#   'lords'],
#  ['past',
#   'the',
#   'sprawl',
#   'of',
#   'the',
#   'camp',
#   'the',
#   'anchorage',
#   'was',
#   'crowded',
#   'with',
#   'ships'],
#  ['no',
#   'craft',
#   'that',
#   'had',
#   'come',
#   'within',
#   'sight',
#   'of',
#   'dragonstone',
#   'this',
#   'past',
#   'half',
#   'year',
#   'had',
#   'been',
#   'allowed',
#   'to',
#   'leave',
#   'again'],
#  ['lord',
#   'stannis',
#   'fury',
#   'triple',
#   'decked',
#   'war',
#   'galley',
#   'of',
#   'three',
#   'hundred',
#   'oars',
#   'looked',
#   'almost',
#   'small',
#   'beside',
#   'some',
#   'of',
#   'the',
#   'big',
#   'bellied',
#   'carracks',
#   'and',
#   'cogs',
#   'that',
#   'surrounded',
#   'her'],
#  ['the',
#   'guardsmen',
#   'outside',
#   'the',
#   'stone',
#   'drum',
#   'knew',
#   'the',
#   'maesters',
#   'by',
#   'sight',
#   'and',
#   'passed',
#   'them',
#   'through'],
#  ['wait', 'here', 'cressen', 'told', 'pylos', 'within'],
#  ['it', 'best', 'see', 'him', 'alone'],
#  ['it', 'is', 'long', 'climb', 'maester'],
#  ['cressen', 'smiled'],
#  ['you', 'think', 'have', 'forgotten'],
#  ['have',
#   'climbed',
#   'these',
#   'steps',
#   'so',
#   'often',
#   'know',
#   'each',
#   'one',
#   'by',
#   'name'],
#  ['halfway', 'up', 'he', 'regretted', 'his', 'decision'],
#  ['he',
#   'had',
#   'stopped',
#   'to',
#   'catch',
#   'his',
#   'breath',
#   'and',
#   'ease',
#   'the',
#   'pain',
#   'in',
#   'his',
#   'hip',
#   'when',
#   'he',
#   'heard',
#   'the',
#   'scuff',
#   'of',
#   'boots',
#   'on',
#   'stone',
#   'and',
#   'came',
#   'face',
#   'to',
#   'face',
#   'with',
#   'ser',
#   'davos',
#   'seaworth',
#   'descending'],
#  ['davos',
#   'was',
#   'slight',
#   'man',
#   'his',
#   'low',
#   'birth',
#   'written',
#   'plain',
#   'upon',
#   'common',
#   'face'],
#  ['well',
#   'worn',
#   'green',
#   'cloak',
#   'stained',
#   'by',
#   'salt',
#   'and',
#   'spray',
#   'and',
#   'faded',
#   'from',
#   'the',
#   'sun',
#   'draped',
#   'his',
#   'thin',
#   'shoulders',
#   'over',
#   'brown',
#   'doublet',
#   'and',
#   'breeches',
#   'that',
#   'matched',
#   'brown',
#   'eyes',
#   'and',
#   'hair'],
#  ['about',
#   'his',
#   'neck',
#   'pouch',
#   'of',
#   'worn',
#   'leather',
#   'hung',
#   'from',
#   'thong'],
#  ['his',
#   'small',
#   'beard',
#   'was',
#   'well',
#   'peppered',
#   'with',
#   'grey',
#   'and',
#   'he',
#   'wore',
#   'leather',
#   'glove',
#   'on',
#   'his',
#   'maimed',
#   'left',
#   'hand'],
#  ['when', 'he', 'saw', 'cressen', 'he', 'checked', 'his', 'descent'],
#  ['ser', 'davos', 'the', 'maester', 'said'],
#  ['when', 'did', 'you', 'return'],
#  ['in', 'the', 'black', 'of', 'morning'],
#  ['my', 'favorite', 'time'],
#  ['it',
#   'was',
#   'said',
#   'that',
#   'no',
#   'one',
#   'had',
#   'ever',
#   'handled',
#   'ship',
#   'by',
#   'night',
#   'half',
#   'so',
#   'well',
#   'as',
#   'davos',
#   'shorthand'],
#  ['before',
#   'lord',
#   'stannis',
#   'had',
#   'knighted',
#   'him',
#   'he',
#   'had',
#   'been',
#   'the',
#   'most',
#   'notorious',
#   'and',
#   'elusive',
#   'smuggler',
#   'in',
#   'all',
#   'the',
#   'seven',
#   'kingdoms'],
#  ['and'],
#  ['the', 'man', 'shook', 'his', 'head'],
#  ['it', 'is', 'as', 'you', 'warned', 'him'],
#  ['they', 'will', 'not', 'rise', 'maester'],
#  ['not', 'for', 'him'],
#  ['they', 'do', 'not', 'love', 'him'],
#  ['no', 'cressen', 'thought'],
#  ['nor', 'will', 'they', 'ever'],
#  ['he', 'is', 'strong', 'able', 'just'],
#  [],
#  [],
#  ['aye', 'just', 'past', 'the', 'point', 'of', 'wisdom'],
#  [],
#  [],
#  ['yet', 'it', 'is', 'not', 'enough'],
#  ['it', 'has', 'never', 'been', 'enough'],
#  ['you', 'spoke', 'to', 'them', 'all'],
#  ['page', 'all'],
#  ['no'],
#  ['only', 'those', 'that', 'would', 'see', 'me'],
#  ['they', 'do', 'not', 'love', 'me', 'either', 'these', 'highborns'],
#  ['to', 'them', 'll', 'always', 'be', 'the', 'onion', 'knight'],
#  ['his',
#   'left',
#   'hand',
#   'closed',
#   'stubby',
#   'fingers',
#   'locking',
#   'into',
#   'fist',
#   'stannis',
#   'had',
#   'hacked',
#   'the',
#   'ends',
#   'off',
#   'at',
#   'the',
#   'last',
#   'joint',
#   'all',
#   'but',
#   'the',
#   'thumb'],
#  ['broke',
#   'bread',
#   'with',
#   'gulian',
#   'swann',
#   'and',
#   'old',
#   'penrose',
#   'and',
#   'the',
#   'tarths',
#   'consented',
#   'to',
#   'midnight',
#   'meeting',
#   'in',
#   'grove'],
#  ['the',
#   'others',
#   'well',
#   'beric',
#   'dondarrion',
#   'is',
#   'gone',
#   'missing',
#   'some',
#   'say',
#   'dead',
#   'and',
#   'lord',
#   'caron',
#   'is',
#   'with',
#   'renly'],
#  ['bryce', 'the', 'orange', 'of', 'the', 'rainbow', 'guard'],
#  ['the', 'rainbow', 'guard'],
#  ['renly',
#   'made',
#   'his',
#   'own',
#   'kingsguard',
#   'the',
#   'onetime',
#   'smuggler',
#   'explained',
#   'but',
#   'these',
#   'seven',
#   'don',
#   'wear',
#   'white'],
#  ['each', 'one', 'has', 'his', 'own', 'color'],
#  ['loras', 'tyrell', 'their', 'lord', 'commander'],
#  ['it',
#   'was',
#   'just',
#   'the',
#   'sort',
#   'of',
#   'notion',
#   'that',
#   'would',
#   'appeal',
#   'to',
#   'renly',
#   'baratheon',
#   'splendid',
#   'new',
#   'order',
#   'of',
#   'knighthood',
#   'with',
#   'gorgeous',
#   'new',
#   'raiment',
#   'to',
#   'proclaim',
#   'it'],
#  ['even',
#   'as',
#   'boy',
#   'renly',
#   'had',
#   'loved',
#   'bright',
#   'colors',
#   'and',
#   'rich',
#   'fabrics',
#   'and',
#   'he',
#   'had',
#   'loved',
#   'his',
#   'games',
#   'as',
#   'well'],
#  ['look', 'at', 'me'],
#  ['he',
#   'would',
#   'shout',
#   'as',
#   'he',
#   'ran',
#   'laughing',
#   'through',
#   'the',
#   'halls',
#   'of',
#   'storm',
#   'end'],
#  ['look',
#   'at',
#   'me',
#   'dragon',
#   'or',
#   'look',
#   'at',
#   'me',
#   'wizard',
#   'or',
#   'look',
#   'at',
#   'me',
#   'look',
#   'at',
#   'me',
#   'the',
#   'rain',
#   'god'],
#  ['the',
#   'bold',
#   'little',
#   'boy',
#   'with',
#   'wild',
#   'black',
#   'hair',
#   'and',
#   'laughing',
#   'eyes',
#   'was',
#   'man',
#   'grown',
#   'now',
#   'one',
#   'and',
#   'twenty',
#   'and',
#   'still',
#   'he',
#   'played',
#   'his',
#   'games'],
#  ['look', 'at', 'me', 'king', 'cressen', 'thought', 'sadly'],
#  ['oh',
#   'renly',
#   'renly',
#   'dear',
#   'sweet',
#   'child',
#   'do',
#   'you',
#   'know',
#   'what',
#   'you',
#   'are',
#   'doing',
#   'and',
#   'would',
#   'you',
#   'care',
#   'if',
#   'you',
#   'did'],
#  ['is',
#   'there',
#   'anyone',
#   'who',
#   'cares',
#   'for',
#   'him',
#   'but',
#   'me',
#   'what',
#   'reasons',
#   'did',
#   'the',
#   'lords',
#   'give',
#   'for',
#   'their',
#   'refusals'],
#  ['he', 'asked', 'ser', 'davos'],
#  ['well',
#   'as',
#   'to',
#   'that',
#   'some',
#   'gave',
#   'me',
#   'soft',
#   'words',
#   'and',
#   'some',
#   'blunt',
#   'some',
#   'made',
#   'excuses',
#   'some',
#   'promises',
#   'some',
#   'only',
#   'lied'],
#  ['he', 'shrugged'],
#  ['in', 'the', 'end', 'words', 'are', 'just', 'wind'],
#  ['you', 'could', 'bring', 'him', 'no', 'hope'],
#  ['only', 'the', 'false', 'sort', 'and', 'not', 'do', 'that', 'davos', 'said'],
#  ['he', 'had', 'the', 'truth', 'from', 'me'],
#  ['maester',
#   'cressen',
#   'remembered',
#   'the',
#   'day',
#   'davos',
#   'had',
#   'been',
#   'knighted',
#   'after',
#   'the',
#   'siege',
#   'of',
#   'storm',
#   'end'],
#  ['lord',
#   'stannis',
#   'and',
#   'small',
#   'garrison',
#   'had',
#   'held',
#   'the',
#   'castle',
#   'for',
#   'close',
#   'to',
#   'year',
#   'against',
#   'the',
#   'great',
#   'host',
#   'of',
#   'the',
#   'lords',
#   'tyrell',
#   'and',
#   'redwyne'],
#  ['even',
#   'the',
#   'sea',
#   'was',
#   'closed',
#   'against',
#   'them',
#   'watched',
#   'day',
#   'and',
#   'night',
#   'by',
#   'redwyne',
#   'galleys',
#   'flying',
#   'the',
#   'burgundy',
#   'banners',
#   'of',
#   'the',
#   'arbor'],
#  ['within',
#   'storm',
#   'end',
#   'the',
#   'horses',
#   'had',
#   'long',
#   'since',
#   'been',
#   'eaten',
#   'the',
#   'dogs',
#   'and',
#   'cats',
#   'were',
#   'gone',
#   'and',
#   'the',
#   'garrison',
#   'was',
#   'down',
#   'to',
#   'roots',
#   'and',
#   'rats'],
#  ['then',
#   'came',
#   'night',
#   'when',
#   'the',
#   'moon',
#   'was',
#   'new',
#   'and',
#   'black',
#   'clouds',
#   'hid',
#   'the',
#   'stars'],
#  ['cloaked',
#   'in',
#   'that',
#   'darkness',
#   'davos',
#   'the',
#   'smuggler',
#   'had',
#   'dared',
#   'the',
#   'redwyne',
#   'cordon',
#   'and',
#   'the',
#   'rocks',
#   'of',
#   'shipbreaker',
#   'bay',
#   'alike'],
#  ['his',
#   'little',
#   'ship',
#   'had',
#   'black',
#   'hull',
#   'black',
#   'sails',
#   'black',
#   'oars',
#   'and',
#   'hold',
#   'crammed',
#   'with',
#   'onions',
#   'and',
#   'salt',
#   'fish'],
#  ['little',
#   'enough',
#   'yet',
#   'it',
#   'had',
#   'kept',
#   'the',
#   'garrison',
#   'alive',
#   'long',
#   'enough',
#   'for',
#   'eddard',
#   'stark',
#   'to',
#   'reach',
#   'storm',
#   'end',
#   'and',
#   'break',
#   'the',
#   'siege'],
#  ['lord',
#   'stannis',
#   'had',
#   'rewarded',
#   'davos',
#   'with',
#   'choice',
#   'lands',
#   'on',
#   'cape',
#   'wrath',
#   'small',
#   'keep',
#   'and',
#   'knight',
#   'honors'],
#  [],
#  [],
#  ['but',
#   'he',
#   'had',
#   'also',
#   'decreed',
#   'that',
#   'he',
#   'lose',
#   'joint',
#   'of',
#   'each',
#   'finger',
#   'on',
#   'his',
#   'left',
#   'hand',
#   'to',
#   'pay',
#   'for',
#   'all',
#   'his',
#   'years',
#   'of',
#   'smuggling'],
#  ['davos',
#   'had',
#   'submitted',
#   'on',
#   'the',
#   'condition',
#   'that',
#   'stannis',
#   'wield',
#   'the',
#   'knife',
#   'himself',
#   'he',
#   'would',
#   'accept',
#   'no',
#   'punishment',
#   'from',
#   'lesser',
#   'hands'],
#  ['the',
#   'lord',
#   'had',
#   'used',
#   'butcher',
#   'cleaver',
#   'the',
#   'better',
#   'to',
#   'cut',
#   'clean',
#   'and',
#   'true'],
#  ['afterward',
#   'davos',
#   'had',
#   'chosen',
#   'the',
#   'name',
#   'seaworth',
#   'for',
#   'his',
#   'new',
#   'made',
#   'house',
#   'and',
#   'he',
#   'took',
#   'for',
#   'his',
#   'banner',
#   'black',
#   'ship',
#   'on',
#   'pale',
#   'grey',
#   'field',
#   'with',
#   'an',
#   'onion',
#   'on',
#   'its',
#   'sails'],
#  ['the',
#   'onetime',
#   'smuggler',
#   'was',
#   'fond',
#   'of',
#   'saying',
#   'that',
#   'lord',
#   'stannis',
#   'had',
#   'done',
#   'him',
#   'boon',
#   'by',
#   'giving',
#   'him',
#   'four',
#   'less',
#   'fingernails',
#   'to',
#   'clean',
#   'and',
#   'trim'],
#  ['no',
#   'cressen',
#   'thought',
#   'man',
#   'like',
#   'that',
#   'would',
#   'give',
#   'no',
#   'false',
#   'hope',
#   'nor',
#   'soften',
#   'hard',
#   'truth'],
#  ['ser',
#   'davos',
#   'truth',
#   'can',
#   'be',
#   'bitter',
#   'draught',
#   'even',
#   'for',
#   'man',
#   'like',
#   'lord',
#   'stannis'],
#  ['he',
#   'thinks',
#   'only',
#   'of',
#   'returning',
#   'to',
#   'king',
#   'landing',
#   'in',
#   'the',
#   'fullness',
#   'of',
#   'his',
#   'power',
#   'to',
#   'tear',
#   'down',
#   'his',
#   'enemies',
#   'and',
#   'claim',
#   'what',
#   'is',
#   'rightfully',
#   'his'],
#  ['yet', 'now'],
#  [],
#  [],
#  ['page',
#   'if',
#   'he',
#   'takes',
#   'this',
#   'meager',
#   'host',
#   'to',
#   'king',
#   'landing',
#   'it',
#   'will',
#   'be',
#   'only',
#   'to',
#   'die'],
#  ['he', 'does', 'not', 'have', 'the', 'numbers'],
#  ['told', 'him', 'as', 'much', 'but', 'you', 'know', 'his', 'pride'],
#  ['davos', 'held', 'up', 'his', 'gloved', 'hand'],
#  ['my',
#   'fingers',
#   'will',
#   'grow',
#   'back',
#   'before',
#   'that',
#   'man',
#   'bends',
#   'to',
#   'sense'],
#  ['the', 'old', 'man', 'sighed'],
#  ['you', 'have', 'done', 'all', 'you', 'could'],
#  ['now', 'must', 'add', 'my', 'voice', 'to', 'yours'],
#  ['wearily', 'he', 'resumed', 'his', 'climb'],
#  ['lord',
#   'stannis',
#   'baratheon',
#   'refuge',
#   'was',
#   'great',
#   'round',
#   'room',
#   'with',
#   'walls',
#   'of',
#   'bare',
#   'black',
#   'stone',
#   'and',
#   'four',
#   'tall',
#   'narrow',
#   'windows',
#   'that',
#   'looked',
#   'out',
#   'to',
#   'the',
#   'four',
#   'points',
#   'of',
#   'the',
#   'compass'],
#  ['in',
#   'the',
#   'center',
#   'of',
#   'the',
#   'chamber',
#   'was',
#   'the',
#   'great',
#   'table',
#   'from',
#   'which',
#   'it',
#   'took',
#   'its',
#   'name',
#   'massive',
#   'slab',
#   'of',
#   'carved',
#   'wood',
#   'fashioned',
#   'at',
#   'the',
#   'command',
#   'of',
#   'aegon',
#   'targaryen',
#   'in',
#   'the',
#   'days',
#   'before',
#   'the',
#   'conquest'],
#  ['the',
#   'painted',
#   'table',
#   'was',
#   'more',
#   'than',
#   'fifty',
#   'feet',
#   'long',
#   'perhaps',
#   'half',
#   'that',
#   'wide',
#   'at',
#   'its',
#   'widest',
#   'point',
#   'but',
#   'less',
#   'than',
#   'four',
#   'feet',
#   'across',
#   'at',
#   'its',
#   'narrowest'],
#  ['aegon',
#   'carpenters',
#   'had',
#   'shaped',
#   'it',
#   'after',
#   'the',
#   'land',
#   'of',
#   'westeros',
#   'sawing',
#   'out',
#   'each',
#   'bay',
#   'and',
#   'peninsula',
#   'until',
#   'the',
#   'table',
#   'nowhere',
#   'ran',
#   'straight'],
#  ['on',
#   'its',
#   'surface',
#   'darkened',
#   'by',
#   'near',
#   'three',
#   'hundred',
#   'years',
#   'of',
#   'varnish',
#   'were',
#   'painted',
#   'the',
#   'seven',
#   'kingdoms',
#   'as',
#   'they',
#   'had',
#   'been',
#   'in',
#   'aegon',
#   'day',
#   'rivers',
#   'and',
#   'mountains',
#   'castles',
#   'and',
#   'cities',
#   'lakes',
#   'and',
#   'forests'],
#  ['there',
#   'was',
#   'single',
#   'chair',
#   'in',
#   'the',
#   'room',
#   'carefully',
#   'positioned',
#   'in',
#   'the',
#   'precise',
#   'place',
#   'that',
#   'dragonstone',
#   'occupied',
#   'off',
#   'the',
#   'coast',
#   'of',
#   'westeros',
#   'and',
#   'raised',
#   'up',
#   'to',
#   'give',
#   'good',
#   'view',
#   'of',
#   'the',
#   'tabletop'],
#  ['seated',
#   'in',
#   'the',
#   'chair',
#   'was',
#   'man',
#   'in',
#   'tight',
#   'laced',
#   'leather',
#   'jerkin',
#   'and',
#   'breeches',
#   'of',
#   'roughspun',
#   'brown',
#   'wool'],
#  ['when', 'maester', 'cressen', 'entered', 'he', 'glanced', 'up'],
#  ['knew',
#   'you',
#   'would',
#   'come',
#   'old',
#   'man',
#   'whether',
#   'summoned',
#   'you',
#   'or',
#   'no'],
#  ['there',
#   'was',
#   'no',
#   'hint',
#   'of',
#   'warmth',
#   'in',
#   'his',
#   'voice',
#   'there',
#   'seldom',
#   'was'],
#  ['stannis',
#   'baratheon',
#   'lord',
#   'of',
#   'dragonstone',
#   'and',
#   'by',
#   'the',
#   'grace',
#   'of',
#   'the',
#   'gods',
#   'rightful',
#   'heir',
#   'to',
#   'the',
#   'iron',
#   'throne',
#   'of',
#   'the',
#   'seven',
#   'kingdoms',
#   'of',
#   'westeros',
#   'was',
#   'broad',
#   'of',
#   'shoulder',
#   'and',
#   'sinewy',
#   'of',
#   'limb',
#   'with',
#   'tightness',
#   'to',
#   'his',
#   'face',
#   'and',
#   'flesh',
#   'that',
#   'spoke',
#   'of',
#   'leather',
#   'cured',
#   'in',
#   'the',
#   'sun',
#   'until',
#   'it',
#   'was',
#   'as',
#   'tough',
#   'as',
#   'steel'],
#  ['hard',
#   'was',
#   'the',
#   'word',
#   'men',
#   'used',
#   'when',
#   'they',
#   'spoke',
#   'of',
#   'stannis',
#   'and',
#   'hard',
#   'he',
#   'was'],
#  ['though',
#   'he',
#   'was',
#   'not',
#   'yet',
#   'five',
#   'and',
#   'thirty',
#   'only',
#   'fringe',
#   'of',
#   'thin',
#   'black',
#   'hair',
#   'remained',
#   'on',
#   'his',
#   'head',
#   'circling',
#   'behind',
#   'his',
#   'ears',
#   'like',
#   'the',
#   'shadow',
#   'of',
#   'crown'],
#  ['his',
#   'brother',
#   'the',
#   'late',
#   'king',
#   'robert',
#   'had',
#   'grown',
#   'beard',
#   'in',
#   'his',
#   'final',
#   'years'],
#  ['maester',
#   'cressen',
#   'had',
#   'never',
#   'seen',
#   'it',
#   'but',
#   'they',
#   'said',
#   'it',
#   'was',
#   'wild',
#   'thing',
#   'thick',
#   'and',
#   'flerce'],
#  ['as',
#   'if',
#   'in',
#   'answer',
#   'stannis',
#   'kept',
#   'his',
#   'own',
#   'whiskers',
#   'cropped',
#   'tight',
#   'and',
#   'short'],
#  ['they',
#   'lay',
#   'like',
#   'blue',
#   'black',
#   'shadow',
#   'across',
#   'his',
#   'square',
#   'jaw',
#   'and',
#   'the',
#   'bony',
#   'hollows',
#   'of',
#   'his',
#   'cheeks'],
#  ['his',
#   'eyes',
#   'were',
#   'open',
#   'wounds',
#   'beneath',
#   'his',
#   'heavy',
#   'brows',
#   'blue',
#   'as',
#   'dark',
#   'as',
#   'the',
#   'sea',
#   'by',
#   'night'],
#  ['his',
#   'mouth',
#   'would',
#   'have',
#   'given',
#   'despair',
#   'to',
#   'even',
#   'the',
#   'drollest',
#   'of',
#   'fools',
#   'it',
#   'was',
#   'mouth',
#   'made',
#   'for',
#   'frowns',
#   'and',
#   'scowls',
#   'and',
#   'sharply',
#   'worded',
#   'commands',
#   'all',
#   'thin',
#   'pale',
#   'lips',
#   'and',
#   'clenched',
#   'muscles',
#   'mouth',
#   'that',
#   'had',
#   'forgotten',
#   'how',
#   'to',
#   'smile',
#   'and',
#   'had',
#   'never',
#   'known',
#   'how',
#   'to',
#   'laugh'],
#  ['sometimes',
#   'when',
#   'the',
#   'world',
#   'grew',
#   'very',
#   'still',
#   'and',
#   'silent',
#   'of',
#   'night',
#   'maester',
#   'cressen',
#   'fancied',
#   'he',
#   'could',
#   'hear',
#   'lord',
#   'stannis',
#   'grinding',
#   'his',
#   'teeth',
#   'half',
#   'castle',
#   'away'],
#  ['once', 'you', 'would', 'have', 'woken', 'me', 'the', 'old', 'man', 'said'],
#  ['once', 'you', 'were', 'young'],
#  ['now', 'you', 'are', 'old', 'and', 'sick', 'and', 'need', 'your', 'sleep'],
#  ['stannis',
#   'had',
#   'never',
#   'learned',
#   'to',
#   'soften',
#   'his',
#   'speech',
#   'to',
#   'dissemble',
#   'or',
#   'flatter',
#   'he',
#   'said',
#   'what',
#   'he',
#   'thought',
#   'and',
#   'those',
#   'that',
#   'did',
#   'not',
#   'like',
#   'it',
#   'could',
#   'be',
#   'damned'],
#  ['knew',
#   'you',
#   'learn',
#   'what',
#   'davos',
#   'had',
#   'to',
#   'say',
#   'soon',
#   'enough'],
#  ['you', 'always', 'do', 'don', 'you'],
#  ['would',
#   'be',
#   'of',
#   'no',
#   'help',
#   'to',
#   'you',
#   'if',
#   'did',
#   'not',
#   'cressen',
#   'said'],
#  ['met', 'davos', 'on', 'the', 'stair'],
#  ['and', 'he', 'told', 'all', 'suppose'],
#  ['should',
#   'have',
#   'had',
#   'the',
#   'man',
#   'tongue',
#   'shortened',
#   'along',
#   'with',
#   'his',
#   'fingers'],
#  ['he', 'would', 'have', 'made', 'you', 'poor', 'envoy', 'then'],
#  ['he', 'made', 'me', 'poor', 'envoy', 'in', 'any', 'case'],
#  ['the', 'storm', 'lords', 'will', 'not', 'rise', 'for', 'me'],
#  ['it',
#   'seems',
#   'they',
#   'do',
#   'not',
#   'like',
#   'page',
#   'me',
#   'and',
#   'the',
#   'justice',
#   'of',
#   'my',
#   'cause',
#   'means',
#   'nothing',
#   'to',
#   'them'],
#  ['the',
#   'cravenly',
#   'ones',
#   'will',
#   'sit',
#   'behind',
#   'their',
#   'walls',
#   'waiting',
#   'to',
#   'see',
#   'how',
#   'the',
#   'wind',
#   'rises',
#   'and',
#   'who',
#   'is',
#   'likely',
#   'to',
#   'triumph'],
#  ['the', 'bold', 'ones', 'have', 'already', 'declared', 'for', 'renly'],
#  ['for', 'enly'],
#  ['he', 'spat', 'out', 'the', 'name', 'like', 'poison', 'on', 'his', 'tongue'],
#  ['your',
#   'brother',
#   'has',
#   'been',
#   'the',
#   'lord',
#   'of',
#   'storm',
#   'end',
#   'these',
#   'past',
#   'thirteen',
#   'years'],
#  ['these',
#   'lords',
#   'are',
#   'his',
#   'sworn',
#   'bannermen',
#   'his',
#   'stannis',
#   'broke',
#   'in',
#   'when',
#   'by',
#   'rights',
#   'they',
#   'should',
#   'be',
#   'mine'],
#  ['never', 'asked', 'for', 'dragonstone'],
#  ['never', 'wanted', 'it'],
#  ['took',
#   'it',
#   'because',
#   'robert',
#   'enemies',
#   'were',
#   'here',
#   'and',
#   'he',
#   'commanded',
#   'me',
#   'to',
#   'root',
#   'them',
#   'out'],
#  ['built',
#   'his',
#   'fleet',
#   'and',
#   'did',
#   'his',
#   'work',
#   'dutiful',
#   'as',
#   'younger',
#   'brother',
#   'should',
#   'be',
#   'to',
#   'an',
#   'elder',
#   'as',
#   'renly',
#   'should',
#   'be',
#   'to',
#   'me'],
# ...
#   'mats',
#   'and',
#   'tangles',
#   'with',
#   'his',
#   'dagger'],
#  ['she',
#   'remembered',
#   'how',
#   'the',
#   'breeze',
#   'sent',
#   'the',
#   'fistfuls',
#   'of',
#   'dirty',
#   'brown',
#   'hair',
#   'skittering',
#   'across',
#   'the',
#   'paving',
#   'stones',
#   'toward',
#   'the',
#   'sept',
#   'where',
#   'her',
#   'father',
#   'had',
#   'died'],
#  ['taking',
#   'men',
#   'and',
#   'boys',
#   'from',
#   'the',
#   'city',
#   'yoren',
#   'growled',
#   'as',
#   'the',
#   'sharp',
#   'steel',
#   'scraped',
#   'at',
#   'her',
#   'head'],
#  ['now', 'you', 'hold', 'still', 'boy'],
#  ['by',
#   'the',
#   'time',
#   'he',
#   'had',
#   'finished',
#   'her',
#   'scalp',
#   'was',
#   'nothing',
#   'but',
#   'tufts',
#   'and',
#   'stubble'],
#  ['page',
#   'afterward',
#   'he',
#   'told',
#   'her',
#   'that',
#   'from',
#   'there',
#   'to',
#   'winterfell',
#   'she',
#   'be',
#   'arry',
#   'the',
#   'orphan',
#   'boy'],
#  ['gate', 'shouldn', 'be', 'hard', 'but', 'the', 'road', 'another', 'matter'],
#  ['you', 'got', 'long', 'way', 'to', 'go', 'in', 'bad', 'company'],
#  ['got',
#   'thirty',
#   'this',
#   'time',
#   'men',
#   'and',
#   'boys',
#   'all',
#   'bound',
#   'for',
#   'the',
#   'wall',
#   'and',
#   'don',
#   'be',
#   'thinking',
#   'they',
#   're',
#   'like',
#   'that',
#   'bastard',
#   'brother',
#   'yours'],
#  ['he', 'shook', 'her'],
#  ['lord',
#   'eddard',
#   'gave',
#   'me',
#   'pick',
#   'the',
#   'dungeons',
#   'and',
#   'didn',
#   'find',
#   'no',
#   'little',
#   'lordlings',
#   'down',
#   'there'],
#  ['this',
#   'lot',
#   'half',
#   'them',
#   'would',
#   'turn',
#   'you',
#   'over',
#   'to',
#   'the',
#   'queen',
#   'quick',
#   'as',
#   'spit',
#   'for',
#   'pardon',
#   'and',
#   'maybe',
#   'few',
#   'silvers'],
#  ['the',
#   'other',
#   'half',
#   'do',
#   'the',
#   'same',
#   'only',
#   'they',
#   'rape',
#   'you',
#   'first'],
#  ['so',
#   'you',
#   'keep',
#   'to',
#   'yourself',
#   'and',
#   'make',
#   'your',
#   'water',
#   'in',
#   'the',
#   'woods',
#   'alone'],
#  ['that',
#   'll',
#   'be',
#   'the',
#   'hardest',
#   'part',
#   'the',
#   'pissing',
#   'so',
#   'don',
#   'drink',
#   'no',
#   'more',
#   'you',
#   'need'],
#  ['leaving', 'king', 'landing', 'was', 'easy', 'just', 'like', 'he', 'said'],
#  ['the',
#   'lannister',
#   'guardsmen',
#   'on',
#   'the',
#   'gate',
#   'were',
#   'stopping',
#   'everyone',
#   'but',
#   'yoren',
#   'called',
#   'one',
#   'by',
#   'name',
#   'and',
#   'their',
#   'wagons',
#   'were',
#   'waved',
#   'through'],
#  ['no', 'one', 'spared', 'arya', 'glance'],
#  ['they',
#   'were',
#   'looking',
#   'for',
#   'highborn',
#   'girl',
#   'daughter',
#   'of',
#   'the',
#   'king',
#   'hand',
#   'not',
#   'for',
#   'skinny',
#   'boy',
#   'with',
#   'his',
#   'hair',
#   'chopped',
#   'off'],
#  ['arya', 'never', 'looked', 'back'],
#  ['she',
#   'wished',
#   'the',
#   'rush',
#   'would',
#   'rise',
#   'and',
#   'wash',
#   'the',
#   'whole',
#   'city',
#   'away',
#   'flea',
#   'bottom',
#   'and',
#   'the',
#   'red',
#   'keep',
#   'and',
#   'the',
#   'great',
#   'sept',
#   'and',
#   'everything',
#   'and',
#   'everyone',
#   'too',
#   'especially',
#   'prince',
#   'joffrey',
#   'and',
#   'his',
#   'mother'],
#  ['but',
#   'she',
#   'knew',
#   'it',
#   'wouldn',
#   'and',
#   'anyhow',
#   'sansa',
#   'was',
#   'still',
#   'in',
#   'the',
#   'city',
#   'and',
#   'would',
#   'wash',
#   'away',
#   'too'],
#  ['when',
#   'she',
#   'remembered',
#   'that',
#   'arya',
#   'decided',
#   'to',
#   'wish',
#   'for',
#   'winterfell',
#   'instead'],
#  ['yoren', 'was', 'wrong', 'about', 'the', 'pissing', 'though'],
#  ['that',
#   'wasn',
#   'the',
#   'hardest',
#   'part',
#   'at',
#   'all',
#   'lommy',
#   'greenhands',
#   'and',
#   'hot',
#   'pie',
#   'were',
#   'the',
#   'hardest',
#   'part'],
#  ['orphan', 'boys'],
#  ['yoren',
#   'had',
#   'plucked',
#   'some',
#   'from',
#   'the',
#   'streets',
#   'with',
#   'promises',
#   'of',
#   'food',
#   'for',
#   'their',
#   'bellies',
#   'and',
#   'shoes',
#   'for',
#   'their',
#   'feet'],
#  ['the', 'rest', 'he', 'found', 'in', 'chains'],
#  ['the',
#   'watch',
#   'needs',
#   'good',
#   'men',
#   'he',
#   'told',
#   'them',
#   'as',
#   'they',
#   'set',
#   'out',
#   'but',
#   'you',
#   'lot',
#   'will',
#   'have',
#   'to',
#   'do'],
#  ['yoren',
#   'had',
#   'taken',
#   'grown',
#   'men',
#   'from',
#   'the',
#   'dungeons',
#   'as',
#   'well',
#   'thieves',
#   'and',
#   'poachers',
#   'and',
#   'rapers',
#   'and',
#   'the',
#   'like'],
#  ['the',
#   'worst',
#   'were',
#   'the',
#   'three',
#   'he',
#   'found',
#   'in',
#   'the',
#   'black',
#   'cells',
#   'who',
#   'must',
#   'have',
#   'scared',
#   'even',
#   'him',
#   'because',
#   'he',
#   'kept',
#   'them',
#   'fettered',
#   'hand',
#   'and',
#   'foot',
#   'in',
#   'the',
#   'back',
#   'of',
#   'wagon',
#   'and',
#   'vowed',
#   'they',
#   'stay',
#   'in',
#   'irons',
#   'all',
#   'the',
#   'way',
#   'to',
#   'the',
#   'wall'],
#  ['one',
#   'had',
#   'no',
#   'nose',
#   'only',
#   'the',
#   'hole',
#   'in',
#   'his',
#   'face',
#   'where',
#   'it',
#   'had',
#   'been',
#   'cut',
#   'off',
#   'and',
#   'the',
#   'gross',
#   'fat',
#   'bald',
#   'one',
#   'with',
#   'the',
#   'pointed',
#   'teeth',
#   'and',
#   'the',
#   'weeping',
#   'sores',
#   'on',
#   'his',
#   'cheeks',
#   'had',
#   'eyes',
#   'like',
#   'nothing',
#   'human'],
#  ['they',
#   'took',
#   'five',
#   'wagons',
#   'out',
#   'of',
#   'king',
#   'landing',
#   'laden',
#   'with',
#   'supplies',
#   'for',
#   'the',
#   'wall',
#   'hides',
#   'and',
#   'bolts',
#   'of',
#   'cloth',
#   'bars',
#   'of',
#   'pig',
#   'iron',
#   'cage',
#   'of',
#   'ravens',
#   'books',
#   'and',
#   'paper',
#   'and',
#   'ink',
#   'bale',
#   'of',
#   'sourleaf',
#   'jars',
#   'of',
#   'oil',
#   'and',
#   'chests',
#   'of',
#   'medicine',
#   'and',
#   'spices'],
#  ['teams',
#   'of',
#   'plow',
#   'horses',
#   'pulled',
#   'the',
#   'wagons',
#   'and',
#   'yoren',
#   'had',
#   'bought',
#   'two',
#   'coursers',
#   'and',
#   'half',
#   'dozen',
#   'donkeys',
#   'for',
#   'the',
#   'boys'],
#  ['arya',
#   'would',
#   'have',
#   'preferred',
#   'real',
#   'horse',
#   'but',
#   'the',
#   'donkey',
#   'was',
#   'better',
#   'than',
#   'riding',
#   'on',
#   'wagon'],
#  ['the',
#   'men',
#   'paid',
#   'her',
#   'no',
#   'mind',
#   'but',
#   'she',
#   'was',
#   'not',
#   'so',
#   'lucky',
#   'with',
#   'the',
#   'boys'],
#  ['she',
#   'was',
#   'two',
#   'years',
#   'younger',
#   'than',
#   'the',
#   'youngest',
#   'orphan',
#   'not',
#   'to',
#   'mention',
#   'smaller',
#   'and',
#   'skinnier',
#   'and',
#   'lommy',
#   'and',
#   'hot',
#   'pie',
#   'took',
#   'her',
#   'silence',
#   'to',
#   'mean',
#   'she',
#   'was',
#   'scared',
#   'or',
#   'stupid',
#   'or',
#   'deaf'],
#  ['look',
#   'at',
#   'that',
#   'sword',
#   'lumpyhead',
#   'got',
#   'there',
#   'lommy',
#   'said',
#   'one',
#   'morning',
#   'as',
#   'they',
#   'made',
#   'their',
#   'plodding',
#   'way',
#   'past',
#   'orchards',
#   'and',
#   'wheat',
#   'fields'],
#  ['he',
#   'been',
#   'dyer',
#   'apprentice',
#   'before',
#   'he',
#   'was',
#   'caught',
#   'stealing',
#   'and',
#   'his',
#   'arms',
#   'were',
#   'mottled',
#   'green',
#   'to',
#   'the',
#   'elbow'],
#  ['when',
#   'he',
#   'laughed',
#   'he',
#   'brayed',
#   'like',
#   'the',
#   'donkeys',
#   'they',
#   'were',
#   'riding'],
#  ['where', 'gutter', 'rat', 'like', 'lumpyhead', 'get', 'him', 'sword'],
#  ['arya', 'chewed', 'her', 'lip', 'sullenly'],
#  ['she',
#   'could',
#   'see',
#   'the',
#   'back',
#   'of',
#   'yoren',
#   'faded',
#   'black',
#   'cloak',
#   'up',
#   'ahead',
#   'of',
#   'the',
#   'wagons',
#   'but',
#   'she',
#   'was',
#   'determined',
#   'not',
#   'to',
#   'go',
#   'crying',
#   'to',
#   'him',
#   'for',
#   'help'],
#  ['maybe', 'he', 'little', 'squire', 'hot', 'pie', 'put', 'in'],
#  ['his',
#   'mother',
#   'had',
#   'been',
#   'baker',
#   'before',
#   'she',
#   'died',
#   'and',
#   'he',
#   'pushed',
#   'her',
#   'cart',
#   'through',
#   'the',
#   'streets',
#   'all',
#   'day',
#   'shouting',
#   'hot',
#   'pies'],
#  ['hot', 'pies'],
#  ['some', 'lordy', 'lord', 'little', 'squire', 'boy', 'that', 'it'],
#  ['page', 'he', 'ain', 'no', 'squire', 'look', 'at', 'him'],
#  ['bet', 'that', 'not', 'even', 'real', 'sword'],
#  ['bet', 'it', 'just', 'some', 'play', 'sword', 'made', 'of', 'tin'],
#  ['arya', 'hated', 'them', 'making', 'fun', 'of', 'needle'],
#  ['it',
#   'castle',
#   'forged',
#   'steel',
#   'you',
#   'stupid',
#   'she',
#   'snapped',
#   'turning',
#   'in',
#   'the',
#   'saddle',
#   'to',
#   'glare',
#   'at',
#   'them',
#   'and',
#   'you',
#   'better',
#   'shut',
#   'your',
#   'mouth'],
#  ['the', 'orphan', 'boys', 'hooted'],
#  ['where', 'you', 'get', 'blade', 'like', 'that', 'lumpyface'],
#  ['hot', 'pie', 'wanted', 'to', 'know'],
#  ['lumpyhead', 'corrected', 'lommy'],
#  ['he', 'prob', 'ly', 'stole', 'it'],
#  ['did', 'not'],
#  ['she', 'shouted'],
#  ['jon', 'snow', 'had', 'given', 'her', 'needle'],
#  ['maybe',
#   'she',
#   'had',
#   'to',
#   'let',
#   'them',
#   'call',
#   'her',
#   'lumpyhead',
#   'but',
#   'she',
#   'wasn',
#   'going',
#   'to',
#   'let',
#   'them',
#   'call',
#   'jon',
#   'thief'],
#  ['if',
#   'he',
#   'stole',
#   'it',
#   'we',
#   'could',
#   'take',
#   'it',
#   'off',
#   'him',
#   'said',
#   'hot',
#   'pie'],
#  ['it', 'not', 'his', 'anyhow'],
#  ['could', 'use', 'me', 'sword', 'like', 'that'],
#  ['lommy', 'egged', 'him', 'on'],
#  ['go', 'on', 'take', 'it', 'off', 'him', 'dare', 'you'],
#  ['hot', 'pie', 'kicked', 'his', 'donkey', 'riding', 'closer'],
#  ['hey', 'lumpyface', 'you', 'gimme', 'that', 'sword'],
#  ['his',
#   'hair',
#   'was',
#   'the',
#   'color',
#   'of',
#   'straw',
#   'his',
#   'fat',
#   'face',
#   'all',
#   'sunburnt',
#   'and',
#   'peeling'],
#  ['you', 'don', 'know', 'how', 'to', 'use', 'it'],
#  ['yes', 'do', 'arya', 'could', 'have', 'said'],
#  ['killed',
#   'boy',
#   'fat',
#   'boy',
#   'like',
#   'you',
#   'stabbed',
#   'him',
#   'in',
#   'the',
#   'belly',
#   'and',
#   'he',
#   'died',
#   'and',
#   'll',
#   'kill',
#   'you',
#   'too',
#   'if',
#   'you',
#   'don',
#   'let',
#   'me',
#   'alone'],
#  ['only', 'she', 'did', 'not', 'dare'],
#  ['yoren',
#   'didn',
#   'know',
#   'about',
#   'the',
#   'stableboy',
#   'but',
#   'she',
#   'was',
#   'afraid',
#   'of',
#   'what',
#   'he',
#   'might',
#   'do',
#   'if',
#   'he',
#   'found',
#   'out'],
#  ['arya',
#   'was',
#   'pretty',
#   'sure',
#   'that',
#   'some',
#   'of',
#   'the',
#   'other',
#   'men',
#   'were',
#   'killers',
#   'too',
#   'the',
#   'three',
#   'in',
#   'the',
#   'manacles',
#   'for',
#   'sure',
#   'but',
#   'the',
#   'queen',
#   'wasn',
#   'looking',
#   'for',
#   'them',
#   'so',
#   'it',
#   'wasn',
#   'the',
#   'same'],
#  ['look', 'at', 'him', 'brayed', 'lommy', 'greenhands'],
#  ['bet', 'he', 'going', 'to', 'cry', 'now'],
#  ['you', 'want', 'to', 'cry', 'lumpyhead'],
#  ['she',
#   'had',
#   'cried',
#   'in',
#   'her',
#   'sleep',
#   'the',
#   'night',
#   'before',
#   'dreaming',
#   'of',
#   'her',
#   'father'],
#  ['come',
#   'morning',
#   'she',
#   'woken',
#   'red',
#   'eyed',
#   'and',
#   'dry',
#   'and',
#   'could',
#   'not',
#   'have',
#   'shed',
#   'another',
#   'tear',
#   'if',
#   'her',
#   'life',
#   'had',
#   'hung',
#   'on',
#   'it'],
#  ['he', 'going', 'to', 'wet', 'his', 'pants', 'hot', 'pie', 'suggested'],
#  ['leave',
#   'him',
#   'be',
#   'said',
#   'the',
#   'boy',
#   'with',
#   'the',
#   'shaggy',
#   'black',
#   'hair',
#   'who',
#   'rode',
#   'behind',
#   'them'],
#  ['lommy',
#   'had',
#   'named',
#   'him',
#   'the',
#   'bull',
#   'on',
#   'account',
#   'of',
#   'this',
#   'horned',
#   'helm',
#   'he',
#   'had',
#   'that',
#   'he',
#   'polished',
#   'all',
#   'the',
#   'time',
#   'but',
#   'never',
#   'wore'],
#  ['lommy', 'didn', 'dare', 'mock', 'the', 'bull'],
#  ['he',
#   'was',
#   'older',
#   'and',
#   'big',
#   'for',
#   'his',
#   'age',
#   'with',
#   'broad',
#   'chest',
#   'and',
#   'strong',
#   'looking',
#   'arms'],
#  ['you',
#   'better',
#   'give',
#   'hot',
#   'pie',
#   'the',
#   'sword',
#   'arry',
#   'lommy',
#   'said'],
#  ['hot', 'pie', 'wants', 'it', 'bad'],
#  ['he', 'kicked', 'boy', 'to', 'death'],
#  ['he', 'll', 'do', 'the', 'same', 'to', 'you', 'bet'],
#  ['knocked',
#   'him',
#   'down',
#   'and',
#   'kicked',
#   'him',
#   'in',
#   'the',
#   'balls',
#   'and',
#   'kept',
#   'kicking',
#   'him',
#   'there',
#   'until',
#   'he',
#   'was',
#   'dead',
#   'hot',
#   'pie',
#   'boasted'],
#  ['kicked', 'him', 'all', 'to', 'pieces'],
#  ['his',
#   'balls',
#   'were',
#   'broke',
#   'open',
#   'and',
#   'bloody',
#   'and',
#   'his',
#   'cock',
#   'turned',
#   'black'],
#  ['you', 'better', 'gimme', 'the', 'sword'],
#  ['arya', 'slid', 'her', 'practice', 'sword', 'from', 'her', 'belt'],
#  ['you',
#   'can',
#   'have',
#   'this',
#   'one',
#   'she',
#   'told',
#   'hot',
#   'pie',
#   'not',
#   'wanting',
#   'to',
#   'fight'],
#  ['that', 'just', 'some', 'stick'],
#  ['he',
#   'rode',
#   'nearer',
#   'and',
#   'tried',
#   'to',
#   'reach',
#   'over',
#   'for',
#   'needle',
#   'hilt'],
#  ['page',
#   'arya',
#   'made',
#   'the',
#   'stick',
#   'whistle',
#   'as',
#   'she',
#   'laid',
#   'the',
#   'wood',
#   'across',
#   'his',
#   'donkey',
#   'hindquarters'],
#  ['the',
#   'animal',
#   'hawed',
#   'and',
#   'bucked',
#   'dumping',
#   'hot',
#   'pie',
#   'on',
#   'the',
#   'ground'],
#  ['she',
#   'vaulted',
#   'off',
#   'her',
#   'own',
#   'donkey',
#   'and',
#   'poked',
#   'him',
#   'in',
#   'the',
#   'gut',
#   'as',
#   'he',
#   'tried',
#   'to',
#   'get',
#   'up',
#   'and',
#   'he',
#   'sat',
#   'back',
#   'down',
#   'with',
#   'grunt'],
#  ['then',
#   'she',
#   'whacked',
#   'him',
#   'across',
#   'the',
#   'face',
#   'and',
#   'his',
#   'nose',
#   'made',
#   'crack',
#   'like',
#   'branch',
#   'breaking'],
#  ['blood', 'dribbled', 'from', 'his', 'nostrils'],
#  ['when',
#   'hot',
#   'pie',
#   'began',
#   'to',
#   'wail',
#   'arya',
#   'whirled',
#   'toward',
#   'lommy',
#   'greenhands',
#   'who',
#   'was',
#   'sitting',
#   'on',
#   'his',
#   'donkey',
#   'openmouthed'],
#  ['you', 'want', 'some', 'sword', 'too'],
#  ['she', 'yelled', 'but', 'he', 'didn'],
#  ['he',
#   'raised',
#   'dyed',
#   'green',
#   'hands',
#   'in',
#   'front',
#   'of',
#   'his',
#   'face',
#   'and',
#   'squealed',
#   'at',
#   'her',
#   'to',
#   'get',
#   'away'],
#  ['the', 'bull', 'shouted', 'behind', 'you', 'and', 'arya', 'spun'],
#  ['hot',
#   'pie',
#   'was',
#   'on',
#   'his',
#   'knees',
#   'his',
#   'fist',
#   'closing',
#   'around',
#   'big',
#   'jagged',
#   'rock'],
#  ['she',
#   'let',
#   'him',
#   'throw',
#   'it',
#   'ducking',
#   'her',
#   'head',
#   'as',
#   'it',
#   'sailed',
#   'past'],
#  ['then', 'she', 'flew', 'at', 'him'],
#  ['he',
#   'raised',
#   'hand',
#   'and',
#   'she',
#   'hit',
#   'it',
#   'and',
#   'then',
#   'his',
#   'cheek',
#   'and',
#   'then',
#   'his',
#   'knee'],
#  ['he',
#   'grabbed',
#   'for',
#   'her',
#   'and',
#   'she',
#   'danced',
#   'aside',
#   'and',
#   'bounced',
#   'the',
#   'wood',
#   'off',
#   'the',
#   'back',
#   'of',
#   'his',
#   'head'],
#  ['he',
#   'fell',
#   'down',
#   'and',
#   'got',
#   'up',
#   'and',
#   'stumbled',
#   'after',
#   'her',
#   'his',
#   'red',
#   'face',
#   'all',
#   'smeared',
#   'with',
#   'dirt',
#   'and',
#   'blood'],
#  ['arya', 'slid', 'into', 'water', 'dancer', 'stance', 'and', 'waited'],
#  ['when',
#   'he',
#   'came',
#   'close',
#   'enough',
#   'she',
#   'lunged',
#   'right',
#   'between',
#   'his',
#   'legs',
#   'so',
#   'hard',
#   'that',
#   'if',
#   'her',
#   'wooden',
#   'sword',
#   'had',
#   'had',
#   'point',
#   'it',
#   'would',
#   'have',
#   'come',
#   'out',
#   'between',
#   'his',
#   'butt',
#   'cheeks'],
#  ['by',
#   'the',
#   'time',
#   'yoren',
#   'pulled',
#   'her',
#   'off',
#   'him',
#   'hot',
#   'pie',
#   'was',
#   'sprawled',
#   'out',
#   'on',
#   'the',
#   'ground',
#   'with',
#   'his',
#   'breeches',
#   'brown',
#   'and',
#   'smelly',
#   'crying',
#   'as',
#   'arya',
#   'whapped',
#   'him',
#   'over',
#   'and',
#   'over',
#   'and',
#   'over'],
#  ['enough',
#   'the',
#   'black',
#   'brother',
#   'roared',
#   'prying',
#   'the',
#   'stick',
#   'sword',
#   'from',
#   'her',
#   'fingers',
#   'you',
#   'want',
#   'to',
#   'kill',
#   'the',
#   'fool'],
#  ['when',
#   'lommy',
#   'and',
#   'some',
#   'others',
#   'started',
#   'to',
#   'squeal',
#   'the',
#   'old',
#   'man',
#   'turned',
#   'on',
#   'them',
#   'too'],
#  ['shut',
#   'your',
#   'mouths',
#   'or',
#   'll',
#   'be',
#   'shutting',
#   'them',
#   'for',
#   'you'],
#  ['any',
#   'more',
#   'this',
#   'll',
#   'tie',
#   'you',
#   'lot',
#   'behind',
#   'the',
#   'wagons',
#   'and',
#   'drag',
#   'you',
#   'to',
#   'the',
#   'wall'],
#  ['he', 'spat'],
#  ['and', 'that', 'goes', 'twice', 'for', 'you', 'arry'],
#  ['you', 'come', 'with', 'me', 'boy'],
#  ['now',
#   'they',
#   'were',
#   'all',
#   'looking',
#   'at',
#   'her',
#   'even',
#   'the',
#   'three',
#   'chained',
#   'and',
#   'manacled',
#   'in',
#   'the',
#   'back',
#   'of',
#   'the',
#   'wagon'],
#  ['the',
#   'fat',
#   'one',
#   'snapped',
#   'his',
#   'pointy',
#   'teeth',
#   'together',
#   'and',
#   'hissed',
#   'but',
#   'arya',
#   'ignored',
#   'him'],
#  ['the',
#   'old',
#   'man',
#   'dragged',
#   'her',
#   'well',
#   'off',
#   'the',
#   'road',
#   'into',
#   'tangle',
#   'of',
#   'trees',
#   'cursing',
#   'and',
#   'muttering',
#   'all',
#   'the',
#   'while'],
#  ...]

# %%
model = gensim.models.Word2Vec(
    window=10,
    min_count=2
)

# %%
model.build_vocab(story)

# %%
model.train(story, total_examples=model.corpus_count, epochs=model.epochs)
# Out:
# (6576417, 8625265)

# %%
model.wv.most_similar('daenerys')
# Out:
# [('stormborn', 0.8271570801734924),
#  ('targaryen', 0.8063547611236572),
#  ('princess', 0.7700903415679932),
#  ('unburnt', 0.7574939131736755),
#  ('queen', 0.7447258234024048),
#  ('myrcella', 0.7168022394180298),
#  ('aegon', 0.6960858702659607),
#  ('rhaegar', 0.6847195625305176),
#  ('elia', 0.6830253005027771),
#  ('prince', 0.6555269956588745)]

# %%
model.wv.doesnt_match(['jon','rikon','robb','arya','sansa','bran'])
# Out:
# WARNING:gensim.models.keyedvectors:vectors for words {'rikon'} are not present in the model, ignoring these words
# 'jon'

# %%
model.wv.doesnt_match(['jon','sansa','arya'])
# Out:
# 'jon'

# %%
model.wv.doesnt_match(['cersei', 'jaime', 'bronn', 'tyrion'])
# Out:
# 'bronn'

# %%
model.wv.similarity('sansa','cersei')
# Out:
# 0.75405

# %%
model.wv.similarity('ramsey','theon') #

# %%
model.wv['king']
# Out:
# array([ 3.4737244 , -0.96933746, -0.8174121 , -1.2105143 , -2.0170283 ,
#         3.2055602 ,  2.0810726 , -2.2346852 ,  1.9442014 ,  2.560901  ,
#        -0.80232376,  0.2950705 ,  0.15577422, -0.6964461 , -0.10953205,
#        -2.6267426 ,  1.4614868 , -1.6935573 , -2.8768842 , -0.9398576 ,
#         2.3845966 ,  2.622876  , -1.391188  , -1.8576123 ,  1.8601167 ,
#        -0.50387126, -1.8823397 , -0.11124133, -0.32719785,  1.8647921 ,
#        -2.3011384 ,  2.3365257 , -1.0897981 , -1.2566789 ,  1.8343701 ,
#         2.2567105 ,  0.56350046,  0.6463768 , -1.7216417 ,  0.63448083,
#        -3.0973337 , -0.22216158,  1.0075808 ,  2.465577  ,  0.14662829,
#        -2.9991093 ,  0.28094634,  1.5094376 ,  1.5301706 ,  0.59681123,
#        -1.2763504 , -1.9324108 ,  1.6385924 , -0.9092522 , -2.472202  ,
#        -0.62597483, -0.15841933,  0.7907984 ,  1.3810652 ,  0.8537222 ,
#         1.2970146 , -1.3227428 ,  1.6438724 ,  1.6713499 ,  1.2506402 ,
#         0.04115759, -0.02646706,  3.1139536 , -1.8348029 ,  0.7655918 ,
#         0.1676121 , -0.24424978, -0.7758581 , -3.5782988 , -0.97255003,
#         0.06201787,  0.2758824 , -1.8661071 ,  0.4464167 ,  0.15048517,
#        -0.40645903, -2.0756674 , -1.8410828 , -1.3659939 , -0.7089104 ,
#        -2.0239282 ,  0.44671395, -0.3704715 , -0.7979013 ,  1.1778729 ,
#         2.433807  ,  1.3779039 ,  2.627521  , -2.800792  , -2.3780372 ,
#        -0.00620754,  2.1220012 ,  2.4320257 ,  0.1172388 , -0.37012196],
#       dtype=float32)

# %%
model.wv.similarity('arya','sansa')
# Out:
# 0.8441463

# %%
model.wv.similarity('cersei','sansa')
# Out:
# 0.75405

# %%
model.wv.similarity('tywin','sansa')
# Out:
# 0.18455246

# %%
model.wv.get_normed_vectors()
# Out:
# array([[-0.0032715 ,  0.0745816 ,  0.05291718, ..., -0.1322149 ,
#          0.04930267,  0.07133152],
#        [-0.00228766,  0.1250082 ,  0.02164239, ..., -0.15395565,
#         -0.07112788,  0.18665223],
#        [ 0.04109819, -0.15088551, -0.0707784 , ..., -0.05140813,
#          0.10187456, -0.14749137],
#        ...,
#        [-0.00026908,  0.05783787, -0.06871749, ...,  0.00435245,
#          0.05095652, -0.08892963],
#        [ 0.06479625,  0.13512844,  0.04181723, ..., -0.01698709,
#          0.0192446 , -0.10132991],
#        [-0.12476481,  0.18462178, -0.01526222, ...,  0.0312718 ,
#         -0.11035401, -0.03761587]], dtype=float32)

# %%
y = model.wv.index_to_key

# %%
y
# Out:
# ['the',
#  'and',
#  'to',
#  'of',
#  'he',
#  'his',
#  'was',
#  'you',
#  'her',
#  'in',
#  'it',
#  'had',
#  'that',
#  'she',
#  'as',
#  'with',
#  'him',
#  'not',
#  'but',
#  'for',
#  'they',
#  'is',
#  'at',
#  'on',
#  'said',
#  'my',
#  'have',
#  'be',
#  'them',
#  'lord',
#  'no',
#  'from',
#  'were',
#  'would',
#  'me',
#  'your',
#  'one',
#  'all',
#  'when',
#  'will',
#  'ser',
#  'if',
#  'so',
#  'their',
#  'could',
#  'are',
#  'we',
#  'man',
#  'there',
#  'this',
#  'up',
#  'been',
#  'what',
#  'did',
#  'by',
#  'do',
#  'men',
#  'back',
#  'out',
#  'more',
#  'or',
#  'king',
#  'who',
#  'well',
#  'down',
#  'than',
#  'only',
#  'like',
#  'jon',
#  'some',
#  'old',
#  'hand',
#  'even',
#  'too',
#  'before',
#  'never',
#  'tyrion',
#  'an',
#  'off',
#  'see',
#  'know',
#  'into',
#  'made',
#  'father',
#  'now',
#  'eyes',
#  'black',
#  'told',
#  'thought',
#  'lady',
#  'time',
#  'then',
#  'how',
#  'long',
#  'has',
#  'might',
#  'us',
#  'come',
#  'where',
#  'here',
#  'can',
#  'through',
#  'still',
#  'face',
#  'head',
#  'red',
#  'way',
#  'page',
#  'boy',
#  'must',
#  'once',
#  'good',
#  'two',
#  'over',
#  'little',
#  'about',
#  'brother',
#  'took',
#  'came',
#  'other',
#  'though',
#  'again',
#  'say',
#  'night',
#  'three',
#  'should',
#  'away',
#  'queen',
#  'dead',
#  'own',
#  'its',
#  'am',
#  'son',
#  'blood',
#  'take',
#  'go',
#  'half',
#  'make',
#  'arya',
#  'saw',
#  'white',
#  'day',
#  'first',
#  'himself',
#  'jaime',
#  'our',
#  'look',
#  'want',
#  'after',
#  'much',
#  'enough',
#  'tell',
#  'sword',
#  'great',
#  'looked',
#  'bran',
#  'll',
#  'girl',
#  'left',
#  'knew',
#  'asked',
#  'gave',
#  'called',
#  'wall',
#  'every',
#  'heard',
#  'maester',
#  'yet',
#  'let',
#  'went',
#  'sansa',
#  'turned',
#  'why',
#  'need',
#  'behind',
#  'dany',
#  'around',
#  'just',
#  'another',
#  'beneath',
#  'across',
#  'snow',
#  'keep',
#  'gods',
#  'found',
#  'knight',
#  'woman',
#  'gold',
#  'any',
#  'last',
#  'grace',
#  'those',
#  'castle',
#  'think',
#  'many',
#  'feet',
#  'hair',
#  'against',
#  'cersei',
#  'hands',
#  'stark',
#  'stannis',
#  'seemed',
#  'catelyn',
#  'may',
#  'ever',
#  'done',
#  'robb',
#  'find',
#  'mother',
#  'prince',
#  'lannister',
#  'hear',
#  'grey',
#  'name',
#  'robert',
#  'high',
#  'put',
#  'wine',
#  'stone',
#  'horse',
#  'hard',
#  'upon',
#  'iron',
#  'fire',
#  'water',
#  'until',
#  'these',
#  'voice',
#  'gone',
#  'give',
#  'seen',
#  'shall',
#  'better',
#  'always',
#  'years',
#  'ned',
#  'between',
#  'dark',
#  'sam',
#  'place',
#  'cold',
#  'small',
#  'most',
#  'hundred',
#  'winterfell',
#  'stood',
#  'end',
#  'words',
#  'right',
#  'sea',
#  'nothing',
#  'sister',
#  'fingers',
#  'walls',
#  'same',
#  'cloak',
#  'house',
#  'young',
#  'does',
#  'beside',
#  'get',
#  'seven',
#  'mouth',
#  'watch',
#  'door',
#  'green',
#  'big',
#  'under',
#  'few',
#  'sent',
#  'joffrey',
#  'perhaps',
#  'brothers',
#  'almost',
#  'such',
#  'wanted',
#  'true',
#  'while',
#  'leave',
#  'don',
#  'kings',
#  'arms',
#  'light',
#  'wind',
#  'daughter',
#  'herself',
#  'sweet',
#  'others',
#  'lost',
#  'children',
#  'city',
#  'each',
#  'felt',
#  're',
#  'theon',
#  'side',
#  'yes',
#  'best',
#  'very',
#  'die',
#  'brought',
#  'soon',
#  'died',
#  'far',
#  'north',
#  'fear',
#  'lords',
#  'along',
#  'word',
#  'both',
#  'child',
#  'taken',
#  'help',
#  'battle',
#  'new',
#  'brienne',
#  'davos',
#  'something',
#  'mean',
#  'hall',
#  'rest',
#  'wife',
#  'kill',
#  'sons',
#  'strong',
#  'steel',
#  'began',
#  'days',
#  'sound',
#  'past',
#  'tywin',
#  'dragons',
#  'tower',
#  'killed',
#  'life',
#  'arm',
#  'tried',
#  'knights',
#  'free',
#  'thing',
#  'bloody',
#  'pale',
#  'bear',
#  'love',
#  'sat',
#  'bring',
#  'heart',
#  'bed',
#  'horses',
#  'moment',
#  'close',
#  'cut',
#  'smile',
#  'inside',
#  'dragon',
#  'brown',
#  'hot',
#  'four',
#  'death',
#  'silver',
#  'open',
#  'part',
#  'nor',
#  'thousand',
#  'landing',
#  'above',
#  'going',
#  'blue',
#  'air',
#  'please',
#  'bastard',
#  'laughed',
#  'uncle',
#  'rose',
#  'river',
#  'fell',
#  'war',
#  'sun',
#  'wolf',
#  'swords',
#  'golden',
#  'sleep',
#  'without',
#  'speak',
#  'full',
#  'certain',
#  'beyond',
#  'feel',
#  'send',
#  'fight',
#  'got',
#  'tongue',
#  'set',
#  'rode',
#  'thick',
#  'captain',
#  'throat',
#  'fool',
#  'renly',
#  'legs',
#  'deep',
#  'call',
#  'world',
#  'won',
#  'trees',
#  'rock',
#  'honor',
#  'tall',
#  'pulled',
#  'table',
#  'broken',
#  'steps',
#  'things',
#  'women',
#  'next',
#  'heavy',
#  'burned',
#  'oh',
#  'toward',
#  'together',
#  'given',
#  'skin',
#  'mormont',
#  'hodor',
#  'since',
#  'moved',
#  'smiled',
#  'alone',
#  'raised',
#  'ask',
#  'ride',
#  'hope',
#  'eye',
#  'soft',
#  'reached',
#  'second',
#  'remember',
#  've',
#  'remembered',
#  'coming',
#  'dwarf',
#  'hold',
#  'meant',
#  'cannot',
#  'ten',
#  'teeth',
#  'frey',
#  'morning',
#  'else',
#  'throne',
#  'someone',
#  'command',
#  'fat',
#  'which',
#  'truth',
#  'ground',
#  'doubt',
#  'outside',
#  'cup',
#  'known',
#  'wore',
#  'ran',
#  'gate',
#  'held',
#  'room',
#  'jorah',
#  'wed',
#  'ships',
#  'closed',
#  'commander',
#  'matter',
#  'home',
#  'south',
#  'sky',
#  'wood',
#  'storm',
#  'people',
#  'dozen',
#  'ill',
#  'neck',
#  'food',
#  'instead',
#  'near',
#  'talk',
#  'turn',
#  'riverrun',
#  'none',
#  'walder',
#  'below',
#  'lips',
#  'shadow',
#  'watched',
#  'leather',
#  'times',
#  'summer',
#  'moon',
#  'varys',
#  'shoulder',
#  'warm',
#  'tyrell',
#  'caught',
#  'believe',
#  'least',
#  'guards',
#  'boys',
#  'septon',
#  'answer',
#  'wondered',
#  'ice',
#  'blade',
#  'opened',
#  'mine',
#  'shield',
#  'armor',
#  'safe',
#  'six',
#  'kept',
#  'bolton',
#  'return',
#  'wish',
#  'barristan',
#  'used',
#  'smell',
#  'less',
#  'being',
#  'foot',
#  'floor',
#  'squire',
#  'friends',
#  'empty',
#  'run',
#  'followed',
#  'serve',
#  'beard',
#  'cloaks',
#  'wedding',
#  'wrong',
#  'eat',
#  'daenerys',
#  'sight',
#  'flesh',
#  'five',
#  'strength',
#  'baratheon',
#  'ghost',
#  'returned',
#  'nose',
#  'bones',
#  'yellow',
#  'chest',
#  'girls',
#  'god',
#  'covered',
#  'eddard',
#  'hound',
#  'commanded',
#  'says',
#  'crown',
#  'sometimes',
#  'filled',
#  'led',
#  'aye',
#  'yours',
#  'common',
#  'spoke',
#  'show',
#  'flames',
#  'aside',
#  'huge',
#  'fighting',
#  'friend',
#  'crows',
#  'belly',
#  'seem',
#  'breath',
#  'ship',
#  'yard',
#  'gates',
#  'waiting',
#  'within',
#  'looking',
#  'lysa',
#  'wooden',
#  'wet',
#  'realm',
#  'petyr',
#  'asha',
#  'work',
#  'thin',
#  'promised',
#  'use',
#  'wildlings',
#  'bad',
#  'grew',
#  'later',
#  'tree',
#  'onto',
#  'loved',
#  'afraid',
#  'rain',
#  'master',
#  'shoulders',
#  'walked',
#  'shouted',
#  'late',
#  'fall',
#  'aemon',
#  'liked',
#  'remained',
#  'guard',
#  'tommen',
#  'hurt',
#  'passed',
#  'mance',
#  'year',
#  'littlefinger',
#  'taste',
#  'maid',
#  'lay',
#  'drew',
#  'dothraki',
#  'husband',
#  'greyjoy',
#  'song',
#  'spear',
#  'pushed',
#  'realized',
#  'sure',
#  'named',
#  'whispered',
#  'reach',
#  'finally',
#  'stand',
#  'different',
#  'brave',
#  'wolves',
#  'suddenly',
#  'poor',
#  'dog',
#  'stay',
#  'kingsguard',
#  'lannisters',
#  'kingdoms',
#  'stop',
#  'broke',
#  'ears',
#  'drogo',
#  'princess',
#  'burning',
#  'faces',
#  'dream',
#  'axe',
#  'west',
#  'tears',
#  'heir',
#  'darkness',
#  'meereen',
#  'drink',
#  'either',
#  'pointed',
#  'direwolf',
#  'try',
#  'pain',
#  'arryn',
#  'forward',
#  'sworn',
#  'hill',
#  'raven',
#  'lie',
#  'truly',
#  'khal',
#  'seat',
#  'nights',
#  'grown',
#  'ones',
#  'clegane',
#  'dagger',
#  'born',
#  'edmure',
#  'harrenhal',
#  'care',
#  'road',
#  'round',
#  'bronn',
#  'helm',
#  'margaery',
#  'feast',
#  'quick',
#  'understand',
#  'amongst',
#  'meat',
#  'lifted',
#  'longer',
#  'whilst',
#  'reminded',
#  'maybe',
#  'short',
#  'step',
#  'dont',
#  'third',
#  'bit',
#  'pycelle',
#  'stopped',
#  'pretty',
#  'worse',
#  'lands',
#  'sit',
#  'sharp',
#  'save',
#  'knows',
#  'rodrik',
#  'whose',
#  'smoke',
#  'live',
#  'fathers',
#  'pray',
#  'leg',
#  'window',
#  'westeros',
#  'horn',
#  'younger',
#  'balon',
#  'heads',
#  'slaves',
#  'silk',
#  'twenty',
#  'ago',
#  'peace',
#  'pie',
#  'wants',
#  'laugh',
#  'mountain',
#  'low',
#  'east',
#  'blind',
#  'mind',
#  'towers',
#  'myself',
#  'bread',
#  'bright',
#  'sooner',
#  'mad',
#  'older',
#  'coin',
#  'slain',
#  'making',
#  'camp',
#  'salt',
#  'point',
#  'wait',
#  'drowned',
#  'narrow',
#  'septa',
#  'walk',
#  'melisandre',
#  'served',
#  'glanced',
#  'cheeks',
#  'dogs',
#  'reek',
#  'stepped',
#  'often',
#  'touched',
#  'riding',
#  'knife',
#  'quiet',
#  'sort',
#  'shook',
#  'twisted',
#  'naked',
#  'targaryen',
#  'choice',
#  'during',
#  'victarion',
#  'fish',
#  'silence',
#  'forgotten',
#  'luwin',
#  'loras',
#  'hung',
#  'read',
#  'gift',
#  'running',
#  'replied',
#  'fallen',
#  'knees',
#  'aegon',
#  'silent',
#  'fought',
#  'large',
#  'ahead',
#  'needs',
#  'beautiful',
#  'dawn',
#  'kevan',
#  'casterly',
#  'knee',
#  'pass',
#  'themselves',
#  'mud',
#  'cousin',
#  'company',
#  'stupid',
#  'court',
#  'body',
#  'age',
#  'sept',
#  'trying',
#  'top',
#  'dorne',
#  'tully',
#  'sisters',
#  'kind',
#  'swear',
#  'gendry',
#  'meera',
#  'offered',
#  'closer',
#  'leaves',
#  'clothes',
#  'whole',
#  'kiss',
#  'anything',
#  'gregor',
#  'threw',
#  'agreed',
#  'wonder',
#  'whatever',
#  'cat',
#  'pay',
#  'lion',
#  'queens',
#  'climbed',
#  'answered',
#  'saying',
#  'saddle',
#  'wide',
#  'didn',
#  'stars',
#  'comes',
#  'chain',
#  'trust',
#  'hizdahr',
#  'stones',
#  'hed',
#  'host',
#  'trident',
#  'daughters',
#  'pleased',
#  'yourself',
#  'fair',
#  'dry',
#  'insisted',
#  'spears',
#  'ear',
#  'dying',
#  'eight',
#  'fast',
#  'hes',
#  'doors',
#  'carried',
#  'service',
#  'ought',
#  'singer',
#  'woods',
#  'fist',
#  'hour',
#  'mail',
#  'fine',
#  'join',
#  'council',
#  'crossed',
#  'milk',
#  'needed',
#  'thank',
#  'finger',
#  'tent',
#  'names',
#  'doing',
#  'wildling',
#  'land',
#  'win',
#  'shadows',
#  'boots',
#  'helped',
#  'somehow',
#  'crow',
#  'banners',
#  'folk',
#  'letter',
#  'kissed',
#  'screamed',
#  'angry',
#  'pink',
#  'frightened',
#  'bird',
#  'learn',
#  'torch',
#  'alive',
#  'fires',
#  'winter',
#  'watching',
#  'im',
#  'chair',
#  'dragonstone',
#  'harm',
#  'rhaegar',
#  'neither',
#  'serving',
#  'easy',
#  'learned',
#  'standing',
#  'nine',
#  'drunk',
#  'wings',
#  'imp',
#  'question',
#  'sail',
#  'nodded',
#  'eunuch',
#  'bone',
#  'forth',
#  'warned',
#  'field',
#  'slipped',
#  'slow',
#  'slid',
#  'bronze',
#  'ramsay',
#  'priest',
#  'falling',
#  'dreams',
#  'slowly',
#  'harbor',
#  'promise',
#  'atop',
#  'quentyn',
#  'move',
#  'rise',
#  'line',
#  'gilly',
#  'makes',
#  'flowers',
#  'laughter',
#  'slave',
#  'loose',
#  'bay',
#  'earth',
#  'faced',
#  'grass',
#  'declared',
#  'power',
#  'viserys',
#  'lived',
#  'front',
#  'twice',
#  'captains',
#  'because',
#  'happened',
#  'myrcella',
#  'break',
#  'play',
#  'chains',
#  'dance',
#  'cell',
#  'clean',
#  'surely',
#  'oldtown',
#  'whore',
#  'unless',
#  'claim',
#  'pyke',
#  'cried',
#  'fresh',
#  'tarly',
#  'pair',
#  'illyrio',
#  'waters',
#  'aerys',
#  'quite',
#  'sad',
#  'morrow',
#  'thats',
#  'met',
#  'shouting',
#  'game',
#  'already',
#  'laid',
#  'jeyne',
#  'rule',
#  'touch',
#  'eyrie',
#  'ravens',
#  'softly',
#  'count',
#  'mounted',
#  'sense',
#  'afterward',
#  'woke',
#  ...]

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=3)

# %%
X = pca.fit_transform(model.wv.get_normed_vectors())

# %%
X.shape
# Out:
# (17869, 3)

# %%
import plotly.express as px
fig = px.scatter_3d(X[200:300],x=0,y=1,z=2, color=y[200:300])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="3f0d9c9d-93af-4cbb-ba4f-c78ae2cf820b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3f0d9c9d-93af-4cbb-ba4f-c78ae2cf820b")) {                    Plotly.newPlot(                        "3f0d9c9d-93af-4cbb-ba4f-c78ae2cf820b",                        [{"hovertemplate":"color=stark\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cbr\u003e2=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"stark","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"stark","scene":"scene","showlegend":true,"x":[-0.44603366],"y":[-0.5261064],"z":[-0.2920762],"type":"scatter3d"},{"hovertemplate":"color=stannis\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cbr\u003e2=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"stannis","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"stannis","scene":"scene","showlegend":true,"x":[-0.39333826],"y":[-0.6466214],"z":[0.00076906383],"type":"scatter3d"},{"hovertemplate":"color=seemed\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cbr\u003e2=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"seemed","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"seemed","scene":"scene","showlegend":true,"x":[0.009296827],"y":[-0.43420348],"z":[-0.3142276],"type":"scatter3d"},{"hovertemplate":"color=catelyn\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cbr\u003e2=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"catelyn","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"catelyn","scene":"scene","showlegend":true,"x":[-0.24102914],"y":[-0.32273194],"z":[-0.23675495],"type":"scatter3d"},{"hovertemplate":"color=may\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cbr\u003e2=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"may","marker":{"color":"#FFA15A","symbol":"circle"},"mode":"markers","name":"may","scene":"scene","showlegend":true,"x":[-0.52061707],"y":[-0.49406248],"z":[-0.18736652],"type":"scatter3d"},{"hovertemplate":"color=ever\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cbr\u003e2=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ever","marker":{"color":"#19d3f3","symbol":"circle"},"mode":"markers","name":"ever","scene":"scene","showlegend":true,"x":[-0.3986812],"y":[-0.54689646],"z":[-0.0964551],"type":"scatter3d"},{"hovertemplate":"color=done\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cbr\u003e2=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"done","marker":{"color":"#FF6692","symbol":"circle"},"mode":"markers","name":"done","scene":"scene","showlegend":true,"x":[-0.43872884],"y":[-0.6020605],"z":[-0.2827297],"type":"scatter3d"},{"hovertemplate":"color=robb\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cbr\u003e2=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"robb","marker":{"color":"#B6E880","symbol":"circle"},"mode":"markers","name":"robb","scene":"scene","showlegend":true,"x":[-0.3692244],"y":[-0.49718562],"z":[-0.2361833],"type":"scatter3d"},{"hovertemplate":"color=find\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cbr\u003e2=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"find","marker":{"color":"#FF97FF","symbol":"circle"},"mode":"markers","name":"find","scene":"scene","showlegend":true,"x":[-0.32421768],"y":[-0.60998064],"z":[-0.38264287],"type":"scatter3d"},{"hovertemplate":"color=mother\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cbr\u003e2=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"mother","marker":{"color":"#FECB52","symbol":"circle"},"mode":"markers","name":"mother","scene":"scene","showlegend":true,"x":[-0.4373553],"y":[-0.5212703],"z":[-0.17879698],"type":"scatter3d"},{"hovertemplate":"color=prince\u003cbr\u003e0= ...
